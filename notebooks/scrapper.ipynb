# %%
import os

import requests
from bs4 import BeautifulSoup
import re
import json

# %%
os.chdir(os.path.join(os.path.expanduser("~"),'hypercardio'))

# %%
BASE_PATH = 'https://www.drugs.com'
EFFECT_MAPPING = {'int_3': 'Major','int_2': 'Moderate','int_0':'Unknown','int_1':'Minor' }
ID_REGEX = re.compile('(?<=\w-)\d+-\d+-\d+-\d+(?=\.html)')

# %%
with open('data/links_to_drugs.json','r') as fp:
    links_general = json.load(fp)

# %%
from functools import wraps

def write_file(filename: str, soup: BeautifulSoup) -> None:
    with open(os.path.join('data/scraped',filename),'w+') as fp:
        fp.write(str(soup))

def read_file(filename: str) -> BeautifulSoup:
    with open(os.path.join('data/scraped',filename),'r+') as fp:
        soup = BeautifulSoup(fp, 'html.parser')
    return soup


def log_soup(f):
    @wraps(f)
    def wrap(*args, **kwargs):
        url = kwargs['url']
        temp_url = url.replace('/','$')
        if temp_url not in os.listdir('data/scraped'):
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            write_file(temp_url,soup)
        else:
            soup = read_file(temp_url)
        result = f(*args, **kwargs,soup=soup)
        return result
    return wrap

# %%
def extract_value(line: str):
    values = re.findall(r'(?<=>)([\w\s]+)(?=<\/)',line)
    if values != []:
        return values
    line = BeautifulSoup(line.replace('(','[')).text
    if '[' in line:
        return re.search(r'^([\w\s]+)(?=(\[))',line).group().strip(' ')
    return line

# %%
def get_subtitle_info(soup: BeautifulSoup) -> dict:
    info = {}
    subtitle = (soup.find("p", {"class": "drug-subtitle"}))
    attributes_of_interest = ['Generic name:','Dosage form:','Drug class:']
    for line in str(subtitle).split('\n')[1:]:
        attribute = BeautifulSoup(line).find('b').text
        if attribute in attributes_of_interest:

            attribute_match = re.search(r'(?<=<b>).*(?=:</b>)',line)
            attribute = attribute_match.group()
            value_line = line[attribute_match.span()[1]+6:]
            info[attribute] = extract_value(value_line)
    return info

# %%
def get_sidebar_info(soup: BeautifulSoup) -> dict:

    sidebar_soup = (soup.find("div", {"id": "sidebar"}))
    availability = (sidebar_soup
                    .find('div',{'class':'ddc-accordion'})
                    .find('div',{'class':'ddc-accordion-heading'})
                    .find_all('span')[0].text)
    try:
        rating = (sidebar_soup
                        .find('div',{'class':'ddc-rating-summary'})
                  )
        score = rating.find('div',{'class':'ddc-rating-bar'}).find('span')['style']
        score = re.search(r'(?<=width: ).*(?=%;)',score).group()
        reviews = re.search(r'\d+',rating.find('em').text).group()
    except:
        score = None
        reviews = None
    info = {'availability':availability,
            'score':score,
            'reviews':reviews}
    return info

# %%
def get_description(soup: BeautifulSoup) -> dict:
    pre_desc_header = (soup.find("h2", {"id": "uses"}))
    description = pre_desc_header.findNext('p').text
    side_effects = soup.find('h2',{'id':'side-effects'}).findNext('ul').find_all('li')
    processed_side_effects = []
    for side_effect in side_effects:
        side_effect = side_effect.text.replace(';','').replace(' or','').strip(' ')
        side_effect = re.sub(r'-.+','',side_effect)
        processed_side_effects.append(side_effect.strip(' ').replace('.',''))
    return {'description':description,
            'side_effects': processed_side_effects}

# %%
def scrape_tab_urls(soup: BeautifulSoup) -> dict:
    tab_href = (soup
     .find_all('a',href=True))

    interactions_url = [i for i in tab_href if 'drug-interactions' in i['href']][0]
    return {'interactions_url': interactions_url['href'].replace('.html','-index.html')}

# %%
@log_soup
def get_general_info(soup: BeautifulSoup,url=None) -> dict:
    info = {}
    info.update(scrape_tab_urls(soup))
    info.update(get_subtitle_info(soup))
    info.update(get_sidebar_info(soup))
    info.update(get_description(soup))
    return info

# %%
@log_soup
def get_drugs_interactions(soup: BeautifulSoup, url=None) -> dict:
    medicine_interactions_soup =soup.find_all('ul',{'class':'interactions ddc-list-column-2'})
    medicine_interactions = []
    for index,text_box in enumerate(medicine_interactions_soup):
        for medicine_soup in text_box:
            if medicine_soup !='\n':
                if index != len(medicine_interactions_soup)-1: # last text_box contains informations about diseases interactions
                    inner_html = medicine_soup.find('a')
                    medicine_interactions.append({
                        'class': EFFECT_MAPPING[medicine_soup['class'][0]],
                        'name': inner_html.text,
                        'parent_id': '-'.join(ID_REGEX.search(inner_html['href']).group().split('-')[2:]),
                        'id': '-'.join(ID_REGEX.search(inner_html['href']).group().split('-')[:2])
                    })
    return medicine_interactions

@log_soup
def get_diseases_interactions(soup: BeautifulSoup, url=None) -> dict:
    diseases_interactions = []
    diseases_interactions_soup = (soup
        .find_all('ul',{'class':'interactions ddc-list-column-2'})[-1]
        .find_all('li'))
    for diseases_soup in diseases_interactions_soup:
        diseases_interactions.append({
            'name':diseases_soup.find('a').text,
            'class': EFFECT_MAPPING[diseases_soup['class'][0]]
        })

    return diseases_interactions

# %%
errors = []

# %%
from tqdm.auto import tqdm

# %%
import time
import numpy as np

# %%
general_info_list = []
drug_interactions_list = []
diseases_interactions_list = []
scraped_drugs = []
pbar = tqdm(links_general)
for link in pbar:
    if 'pro' not in links_general[link]:
        sleep_time = np.random.randint(0,10)/10
        try:
            general_info: dict = get_general_info(url=BASE_PATH+ links_general[link])
            drug_interactions: list = get_drugs_interactions(url=BASE_PATH+general_info['interactions_url'])
            diseases_interactions: list = get_diseases_interactions(url=BASE_PATH+general_info['interactions_url'])
            general_info_list.append(general_info)
            drug_interactions_list.append(drug_interactions)
            diseases_interactions_list.append(diseases_interactions)
            scraped_drugs.append(link)
        except:
            errors.append(link)
            pbar.set_postfix({'num_errors': len(errors)})
# Out:
#   0%|          | 0/1187 [00:00<?, ?it/s]

# %%
for i in range(len(scraped_drugs)):
    general_info_list[i]['drug name'] = scraped_drugs[i]

# %%
with open('data/general_info.json','w') as fp:
    json.dump(general_info_list,fp)

# %%
general_info_list
# Out:
# [{'interactions_url': '/drug-interactions/aripiprazole,abilify-index.html',
#   'Generic name': ['aripiprazole'],
#   'Drug class': ['Atypical antipsychotics'],
#   'availability': 'Prescription only',
#   'score': '59.8',
#   'reviews': '1',
#   'description': 'Abilify is an antipsychotic medication. It works by changing the actions of chemicals in the brain.',
#   'side_effects': ['\nsevere agitation, distress, restless feeling\n',
#    '\ntwitching uncontrollable movements of your eyes, lips, tongue, face, arms, legs\n',
#    '\nmask\n',
#    '\nseizure (convulsions)\n',
#    '\nsevere nervous system reaction \n',
#    '\nlow blood cell counts \n',
#    '\nhigh blood sugar \n'],
#   'drug name': 'Abilify'},
#  {'interactions_url': '/drug-interactions/aripiprazole,abilify-maintena-index.html',
#   'Generic name': ['aripiprazole'],
#   'Dosage form': 'extended-release intramuscular injection',
#   'Drug class': ['Atypical antipsychotics'],
#   'availability': 'Prescription only',
#   'score': '61.5',
#   'reviews': '49',
#   'description': 'Abilify Maintena (aripiprazole) is a second-generation or atypical antipsychotic used to treat schizophrenia and bipolar I disorder. It is an extended-release injectable suspension of aripiprazole that only has to be given once a month.',
#   'side_effects': ['See "Important information" above',
#    'Stroke (cerebrovascular problems) in elderly people with dementia',
#    'Neuroleptic malignant syndrome (NMS), a serious condition that can lead to death Call your healthcare provider go to the nearest emergency room right away if you have some all of the following symptoms of NMS:\n\nhigh fever\nconfusion\nchanges in pulse, heart rate, and blood pressure\nstiff muscles\nsweating\n\n',
#    'high fever',
#    'confusion',
#    'changes in pulse, heart rate, and blood pressure',
#    'stiff muscles',
#    'sweating',
#    'Uncontrolled body movements (tardive dyskinesia) This medication may cause movements that you cannot control in your face, tongue, other body parts Tardive dyskinesia may not go away, even if you stop receiving Abilify Maintena Tardive dyskinesia may also start after you stop receiving this medication',
#    'Problems with your metabolism such as:\n\nhigh blood sugar (hyperglycemia): Increases in blood sugar can happen in some people who receive this medication Extremely high blood sugar can lead to coma death If you have diabetes risk factors for diabetes (such as being overweight a family history of diabetes), your healthcare provider should check your blood sugar before you start receiving this medication and during your treatment\nCall your healthcare provider if you have any of these symptoms of high blood sugar while receiving Abilify Maintena:\n\nfeel very thirsty\nneed to urinate more than usual\nfeel very hungry\nfeel weak tired\nfeel sick to your stomach\nfeel confused, your breath smells fruity\n\n\nIncreased fat levels (cholesterol and triglycerides) in your blood\nWeight gain You and your healthcare provider should check your weight regularly\n\n',
#    'high blood sugar (hyperglycemia): Increases in blood sugar can happen in some people who receive this medication Extremely high blood sugar can lead to coma death If you have diabetes risk factors for diabetes (such as being overweight a family history of diabetes), your healthcare provider should check your blood sugar before you start receiving this medication and during your treatment\nCall your healthcare provider if you have any of these symptoms of high blood sugar while receiving Abilify Maintena:\n\nfeel very thirsty\nneed to urinate more than usual\nfeel very hungry\nfeel weak tired\nfeel sick to your stomach\nfeel confused, your breath smells fruity\n\n',
#    'feel very thirsty',
#    'need to urinate more than usual',
#    'feel very hungry',
#    'feel weak tired',
#    'feel sick to your stomach',
#    'feel confused, your breath smells fruity',
#    'Increased fat levels (cholesterol and triglycerides) in your blood',
#    'Weight gain You and your healthcare provider should check your weight regularly',
#    'Unusual urges Some people receiving this medication have had unusual urges such as gambling, binge eating eating that you cannot control (compulsive), compulsive shopping and sexual urges If you your family members notice that you are having unusual urges behaviors, talk to your healthcare provider',
#    'Decreased blood pressure (orthostatic hypotension) You may feel lightheaded faint when you rise too quickly from a sitting lying position',
#    'Low white blood cell count',
#    'Seizures (convulsions)',
#    'Problems controlling your body temperature so that you feel too warm See "What should I avoid while receiving Abilify Maintena?"',
#    'Difficulty swallowing'],
#   'drug name': 'Abilify Maintena'},
#  {'interactions_url': '/drug-interactions/abiraterone-index.html',
#   'Generic name': 'abiraterone acetate',
#   'Dosage form': 'oral tablet',
#   'Drug class': ['Miscellaneous antineoplastics'],
#   'availability': 'Prescription only',
#   'score': '83.1',
#   'reviews': '38',
#   'description': 'Abiraterone works by reducing androgen production in the body. Androgens are male hormones that can promote tumor growth in the prostate gland.',
#   'side_effects': ['\nswelling in your ankles feet, pain in your legs\n',
#    '\nfast irregular heartbeats\n',
#    '\na light\n',
#    '\nsevere headache, blurred vision, pounding in your neck ears\n',
#    '\npain burning when you urinate\n',
#    '\nlow red blood cells (anemia) \n',
#    '\nlow blood potassium \n',
#    '\nliver problems \n',
#    '\nlow blood sugar \n'],
#   'drug name': 'Abiraterone'},
#  {'interactions_url': '/drug-interactions/acetaminophen-hydrocodone-index.html',
#   'Generic name': 'acetaminophen and hydrocodone',
#   'Drug class': ['Narcotic analgesic combinations'],
#   'availability': 'Prescription only',
#   'score': '61.1',
#   'reviews': '1',
#   'description': 'Acetaminophen and hydrocodone is a combination medicine used to relieve moderate to moderately severe pain.',
#   'side_effects': ['\nnoisy breathing, sighing, shallow breathing, breathing that stops during sleep\n',
#    '\na light\n',
#    '\nliver problems \n',
#    '\nlow cortisol levels \n',
#    '\nhigh levels of serotonin in the body \n'],
#   'drug name': 'Acetaminophen and Hydrocodone'},
#  {'interactions_url': '/drug-interactions/acetylcysteine-index.html',
#   'Generic name': 'acetylcysteine',
#   'availability': 'Rx and/or OTC',
#   'score': '71.9',
#   'reviews': '26',
#   'description': 'Acetylcysteine is used to help prevent or lessen liver damage caused by taking large quantities of acetaminophen (Tylenol).',
#   'side_effects': ['\nsevere ongoing vomiting\n',
#    '\ncoughing up blood vomit that looks like coffee grounds\n',
#    '\nsigns that the medicine may not be working\n'],
#   'drug name': 'Acetylcysteine'},
#  {'interactions_url': '/drug-interactions/pioglitazone,actos-index.html',
#   'Generic name': ['pioglitazone'],
#   'Drug class': ['Thiazolidinediones'],
#   'availability': 'Prescription only',
#   'score': '48.8',
#   'reviews': '40',
#   'description': 'Actos is an oral diabetes medicine that helps control blood sugar levels.',
#   'side_effects': ['\nshortness of breath (especially when lying down), unusual tiredness, swelling, rapid weight gain\n',
#    '\npink red urine, painful difficult urination, new worsening urge to urinate\n',
#    '\nchanges in your vision\n',
#    '\nsudden unusual pain in your hand, arm, foot\n'],
#   'drug name': 'Actos'},
#  {'interactions_url': '/drug-interactions/acyclovir-index.html',
#   'Generic name': 'acyclovir',
#   'Drug class': ['Purine nucleosides'],
#   'availability': 'Prescription only',
#   'score': '82.1',
#   'reviews': '176',
#   'description': 'Acyclovir is an antiviral drug that is used to treat symptoms of shingles, chickenpox, cold sores and genital herpes which are all caused by herpes viruses. It is also used to prevent having regular outbreaks of genital herpes. Acyclovir will not get rid of the virus infection but does help sores heal faster and helps with pain relief.',
#   'side_effects': ['\neasy bruising bleeding, purple red pinpoint spots under your skin\n',
#    '\nchanges in behavior\n',
#    '\nconfusion, hallucinations\n',
#    '\nsigns of a kidney problem \n'],
#   'drug name': 'Acyclovir'},
#  {'interactions_url': '/drug-interactions/amphetamine-dextroamphetamine,adderall-index.html',
#   'Generic name': ['amphetamine and dextroamphetamine'],
#   'Drug class': ['CNS stimulants'],
#   'availability': 'Prescription only',
#   'score': '75.5',
#   'reviews': '420',
#   'description': 'Adderall is used to treat attention deficit hyperactivity disorder (ADHD) and narcolepsy. Adderall contains a combination of amphetamine and dextroamphetamine. Amphetamine and dextroamphetamine are central nervous system stimulants that affect chemicals in the brain and nerves that contribute to hyperactivity and impulse control.',
#   'side_effects': ['signs of heart problems',
#    'signs of psychosis',
#    'signs of circulation problems',
#    'a seizure (convulsions)',
#    'muscle twitches (tics)',
#    'changes in your vision'],
#   'drug name': 'Adderall'},
#  {'interactions_url': '/drug-interactions/amphetamine-dextroamphetamine,adderall-xr-index.html',
#   'Generic name': ['amphetamine and dextroamphetamine'],
#   'Drug class': ['CNS stimulants'],
#   'availability': 'Prescription only',
#   'score': '79.8',
#   'reviews': '207',
#   'description': 'Adderall XR are central nervous system stimulants that affect chemicals in the brain and nerves that contribute to hyperactivity and impulse control.',
#   'side_effects': ['\nsigns of heart problems\n',
#    '\nsigns of psychosis\n',
#    '\nsigns of circulation problems\n',
#    '\na seizure (convulsions)\n',
#    '\nmuscle twitches (tics)\n',
#    '\nchanges in your vision\n'],
#   'drug name': 'Adderall XR'},
#  {'interactions_url': '/drug-interactions/fluticasone-salmeterol,advair-diskus-index.html',
#   'Generic name': ['fluticasone and salmeterol'],
#   'Drug class': ['Bronchodilator combinations'],
#   'availability': 'Prescription only',
#   'score': '72.3',
#   'reviews': '105',
#   'description': 'Advair Diskus inhalation is a steroid and bronchodilator combination medicine that is used to prevent asthma attacks. It is also used to prevent flare-ups or worsening of chronic obstructive pulmonary disease (COPD) associated with chronic bronchitis and/or emphysema.',
#   'side_effects': ['\nwheezing, choking, other breathing problems after using  Advair Diskus\n',
#    '\nfever, chills, cough with mucus, feeling short of breath\n',
#    '\nchest pain, fast irregular heartbeats, severe headache, pounding in your neck ears\n',
#    '\ntremors, nervousness\n',
#    '\nblurred vision, tunnel vision, eye pain, seeing halos around lights\n',
#    '\nsigns of thrush (a fungal infection)\n',
#    '\nhigh blood sugar\n',
#    '\nlow potassium level\n',
#    '\nsigns of a hormonal disorder\n'],
#   'drug name': 'Advair Diskus'},
#  {'interactions_url': '/drug-interactions/ibuprofen,advil-index.html',
#   'Generic name': ['ibuprofen'],
#   'Drug class': 'Nonsteroidal anti-inflammatory drugs',
#   'availability': 'Rx and/or OTC',
#   'score': '67.6',
#   'reviews': '38',
#   'description': 'Advil is a nonsteroidal anti-inflammatory drug (NSAID). Ibuprofen works by reducing hormones that cause inflammation and pain in the body.',
#   'side_effects': ['\nchanges in your vision\n',
#    '\nshortness of breath (even with mild exertion)\n',
#    '\nswelling rapid weight gain\n',
#    '\na skin rash, no matter how mild\n',
#    '\nsigns of stomach bleeding \n',
#    '\nliver problems \n',
#    '\nlow red blood cells (anemia) \n',
#    '\nkidney problems \n'],
#   'drug name': 'Advil'},
#  {'interactions_url': '/drug-interactions/everolimus,afinitor-index.html',
#   'Generic name': ['everolimus'],
#   'availability': 'Prescription only',
#   'score': '56.1',
#   'reviews': '16',
#   'description': 'Afinitor is a cancer medicine that interferes with the growth of cancer cells and slows their spread in the body.',
#   'side_effects': ['\nblisters ulcers in your mouth, red swollen gums, trouble swallowing\n',
#    '\nlung problems \n',
#    '\nsigns of infection \n',
#    '\nkidney problems \n',
#    '\nliver problems \n',
#    '\nlow blood cell counts \n',
#    '\nany wound that will not heal\n',
#    '\na surgical incision that is red, warm, swollen, painful, bleeding, oozing pus\n'],
#   'drug name': 'Afinitor'},
#  {'interactions_url': '/drug-interactions/erenumab,aimovig-index.html',
#   'Generic name': ['erenumab'],
#   'Drug class': ['CGRP inhibitors'],
#   'availability': 'Prescription only',
#   'score': '48.5',
#   'reviews': '567',
#   'description': 'Aimovig is a monoclonal antibody that blocks the activation of a certain protein that can produce a migraine attack. This protein, called calcitonin gene- related peptide (CGRP), can cause blood vessels to dilate and cause inflammation and migraine headache pain.',
#   'side_effects': ['\nconstipation\n',
#    '\npain, swelling, redness where the medicine was injected\n'],
#   'drug name': 'Aimovig'},
#  {'interactions_url': '/drug-interactions/albuterol-index.html',
#   'Generic name': 'albuterol inhalation',
#   'Drug class': ['Adrenergic bronchodilators'],
#   'availability': 'Prescription only',
#   'score': '31.8',
#   'reviews': '371',
#   'description': 'Albuterol is a bronchodilator that relaxes muscles in the airways and increases air flow to the lungs.',
#   'side_effects': ['\nwheezing, choking, other breathing problems after using this medicine\n',
#    '\nchest pain, fast heart rate, pounding heartbeats fluttering in your chest\n',
#    '\npain burning when you urinate\n',
#    '\nincreased thirst, increased urination, hunger, dry mouth, fruity breath odor, drowsiness, dry skin, blurred vision, weight loss\n',
#    '\nsigns of low potassium \n'],
#   'drug name': 'Albuterol'},
#  {'interactions_url': '/drug-interactions/alectinib,alecensa-index.html',
#   'Generic name': ['alectinib'],
#   'Drug class': ['Multikinase inhibitors'],
#   'availability': 'Prescription only',
#   'score': '90.0',
#   'reviews': '1',
#   'description': 'Alecensa is a cancer medicine that interferes with the growth and spread of cancer cells in the body.',
#   'side_effects': ['\na very slow heart rate\n',
#    '\na light\n',
#    '\nunexplained muscle pain, tenderness, weakness\n',
#    '\nlung problems \n',
#    '\nlow red blood cells (anemia) \n',
#    '\nkidney problems \n',
#    '\nliver problems \n'],
#   'drug name': 'Alecensa'},
#  {'interactions_url': '/drug-interactions/alendronate-index.html',
#   'Generic name': 'alendronate',
#   'Drug class': ['Bisphosphonates'],
#   'availability': 'Prescription only',
#   'score': '22.5',
#   'reviews': '149',
#   'description': 'Alendronate is used to treat osteoporosis caused by menopause, steroid use, or gonadal failure.  alendronate is for use when you have a high risk of bone fracture due to osteoporosis.',
#   'side_effects': ['\nchest pain, new worsening heartburn\n',
#    '\ndifficulty pain when swallowing\n',
#    '\npain burning under the ribs in the back\n',
#    '\nsevere heartburn, burning pain in your upper stomach, coughing up blood\n',
#    '\nnew unusual pain in your thigh hip\n',
#    '\njaw pain, numbness, swelling\n',
#    '\nsevere joint, bone, muscle pain\n',
#    '\nlow calcium levels\n'],
#   'drug name': 'Alendronate'},
#  {'interactions_url': '/drug-interactions/naproxen,aleve-index.html',
#   'Generic name': ['naproxen'],
#   'Drug class': 'Nonsteroidal anti-inflammatory drugs',
#   'availability': 'Rx and/or OTC',
#   'score': '69.1',
#   'reviews': '147',
#   'description': 'Aleve is a nonsteroidal anti-inflammatory drug (NSAID). Naproxen works by reducing hormones that cause inflammation and pain in the body.',
#   'side_effects': ['\nshortness of breath (even with mild exertion)\n',
#    '\nswelling rapid weight gain\n',
#    '\nthe first sign of any skin rash, no matter how mild\n',
#    '\nsigns of stomach bleeding \n',
#    '\nliver problems \n',
#    '\nkidney problems \n',
#    '\nlow red blood cells (anemia) \n',
#    '\nsevere skin reaction \n'],
#   'drug name': 'Aleve'},
#  {'interactions_url': '/drug-interactions/fexofenadine,allegra-index.html',
#   'Generic name': ['fexofenadine'],
#   'Drug class': ['Antihistamines'],
#   'availability': 'Rx and/or OTC',
#   'score': '67.8',
#   'reviews': '89',
#   'description': 'Allegra is an antihistamine that reduces the effects of natural chemical histamine in the body. Histamine can produce symptoms of sneezing, itching, watery eyes, and runny nose.',
#   'side_effects': ['\nnausea, diarrhea, upset stomach\n',
#    '\nmenstrual cramps\n',
#    '\ndrowsiness, tired feeling\n',
#    '\nheadache\n',
#    '\nmuscle back pain\n'],
#   'drug name': 'Allegra'},
#  {'interactions_url': '/drug-interactions/allopurinol-index.html',
#   'Generic name': 'allopurinol',
#   'availability': 'Prescription only',
#   'score': '74.5',
#   'reviews': '82',
#   'description': 'Allopurinol reduces the production of uric acid in the body. Uric acid buildup can lead to gout or kidney stones.',
#   'side_effects': ['\nany skin rash, no matter how mild\n',
#    '\npainful urination, blood in the urine\n',
#    '\nlittle no urination\n',
#    '\neasy bruising, unusual bleeding\n',
#    '\nnumbness, tingling, burning pain\n',
#    '\nworsening gout symptoms\n',
#    '\nliver problems \n'],
#   'drug name': 'Allopurinol'},
#  {'interactions_url': '/drug-interactions/alprazolam-index.html',
#   'Generic name': 'alprazolam',
#   'Drug class': ['Benzodiazepines'],
#   'availability': 'Prescription only',
#   'score': '86.9',
#   'reviews': '1',
#   'description': 'Alprazolam is a benzodiazepine (ben-zoe-dye-AZE-eh-peen). It is thought that it works by enhancing the activity of certain neurotransmitters in the brain.',
#   'side_effects': ['\nweak shallow breathing\n',
#    '\na light\n',
#    '\na seizure\n',
#    '\nhallucinations, risk\n',
#    '\nincreased energy, decreased need for sleep\n',
#    '\nracing thoughts, being agitated talkative\n',
#    '\ndouble vision\n',
#    '\njaundice (yellowing of the skin eyes)\n'],
#   'drug name': 'Alprazolam'},
#  {'interactions_url': '/drug-interactions/brigatinib,alunbrig-index.html',
#   'Generic name': ['brigatinib'],
#   'Drug class': ['Multikinase inhibitors'],
#   'availability': 'Prescription only',
#   'score': None,
#   'reviews': None,
#   'description': 'Alunbrig is a cancer medicine that interferes with the growth and spread of cancer cells in the body.',
#   'side_effects': ['\nlung problems \n',
#    '\nvision problems \n',
#    '\nhigh blood pressure \n',
#    '\nhigh blood sugar \n',
#    '\nheart problems \n',
#    '\nmuscle problems \n',
#    '\npancreatitis \n'],
#   'drug name': 'Alunbrig'},
#  {'interactions_url': '/drug-interactions/amantadine-index.html',
#   'Generic name': 'amantadine',
#   'availability': 'Prescription only',
#   'score': '69.8',
#   'reviews': '41',
#   'description': 'Amantadine is an antiviral medicine that blocks the actions of viruses in your body.',
#   'side_effects': ['\nextreme drowsiness, falling asleep suddenly even after feeling alert\n',
#    '\na light\n',
#    '\nshortness of breath (even with mild exertion), swelling in your hands feet\n',
#    '\npainful difficult urination\n',
#    '\ndepression, agitation, aggression, behavior changes, hallucinations, thoughts of hurting yourself\n',
#    '\na seizure\n',
#    '\nsevere nervous system reaction \n'],
#   'drug name': 'Amantadine'},
#  {'interactions_url': '/drug-interactions/zolpidem,ambien-index.html',
#   'Generic name': ['zolpidem'],
#   'Drug class': 'Miscellaneous anxiolytics, sedatives and hypnotics',
#   'availability': 'Prescription only',
#   'score': '70.1',
#   'reviews': '540',
#   'description': 'Ambien is a sedative, also called a hypnotic. Zolpidem affects chemicals in the brain that may be unbalanced in people with sleep problems insomnia).',
#   'side_effects': ['\nchest pain, fast irregular heartbeat, feeling short of breath\n',
#    '\ntrouble breathing swallowing\n',
#    '\nfeeling like you might pass out\n'],
#   'drug name': 'Ambien'},
#  {'interactions_url': '/drug-interactions/amiodarone-index.html',
#   'Generic name': 'amiodarone tablets',
#   'Drug class': ['Group III antiarrhythmics'],
#   'availability': 'Prescription only',
#   'score': '48.7',
#   'reviews': '88',
#   'description': 'Amiodarone affects the rhythm of your heartbeats. It is used to help keep the heart beating normally in people with life-threatening heart rhythm disorders of the ventricles (the lower chambers of the heart that allow blood to flow out of the heart).',
#   'side_effects': ['\nwheezing, cough, chest pain, cough with bloody mucus, fever\n',
#    '\na new a worsening irregular heartbeat pattern (fast, slow, pounding heartbeats)\n',
#    '\na light\n',
#    '\nblurred vision, seeing halos around lights (your eyes may be more sensitive to light)\n',
#    '\nliver problems \n',
#    '\nnerve problems \n',
#    '\nsigns of overactive thyroid \n',
#    '\nsigns of underactive thyroid \n'],
#   'drug name': 'Amiodarone'},
#  {'interactions_url': '/drug-interactions/amitriptyline-index.html',
#   'Generic name': 'amitriptyline',
#   'Drug class': ['Tricyclic antidepressants'],
#   'availability': 'Prescription only',
#   'score': '75.3',
#   'reviews': '1',
#   'description': 'Amitriptyline is a tricyclic antidepressant with sedative effects. Amitriptyline affects certain chemical messengers (neurotransmitters) that communicate between brain cells and help regulate mood.',
#   'side_effects': ['\nsigns of a blood clot \n',
#    '\nunusual thoughts behavior\n',
#    '\na light\n',
#    '\nchest pain pressure, pain spreading to your jaw shoulder, nausea, sweating\n',
#    '\npounding heartbeats fluttering in your chest\n',
#    '\nconfusion, hallucinations\n',
#    '\na seizure (convulsions)\n',
#    '\npainful difficult urination\n',
#    '\nsevere constipation\n',
#    '\neasy bruising, unusual bleeding\n',
#    '\nfever, chills, sore throat, mouth sores\n'],
#   'drug name': 'Amitriptyline'},
#  {'interactions_url': '/drug-interactions/amlodipine-index.html',
#   'Generic name': 'amlodipine',
#   'Drug class': ['Calcium channel blocking agents'],
#   'availability': 'Prescription only',
#   'score': '41.6',
#   'reviews': '728',
#   'description': 'Amlodipine is used to treat high blood pressure (hypertension), some types of angina and other conditions caused by coronary artery disease. Amlodipine is a calcium channel blocker that works by changing the movement of calcium in the heart and blood vessel cells. This widens the blood vessels which increases the blood and oxygen supply to the heart and also lowers blood pressure.',
#   'side_effects': ['pounding heartbeats fluttering in your chest',
#    'worsening chest pain',
#    'swelling in your feet ankles',
#    'severe drowsiness',
#    'a light'],
#   'drug name': 'Amlodipine'},
#  {'interactions_url': '/drug-interactions/amoxicillin-index.html',
#   'Generic name': 'amoxicillin',
#   'Drug class': ['Aminopenicillins'],
#   'availability': 'Prescription only',
#   'score': '62.5',
#   'reviews': '347',
#   'description': 'Amoxicillin is a penicillin antibiotic that fights bacteria.',
#   'side_effects': ['\nsevere stomach pain\n',
#    '\ndiarrhea that is watery bloody (even if it occurs months after your last dose)\n'],
#   'drug name': 'Amoxicillin'},
#  {'interactions_url': '/drug-interactions/amoxicillin-clavulanate-index.html',
#   'Generic name': 'amoxicillin and clavulanate potassium',
#   'Drug class': 'Beta-lactamase inhibitors',
#   'availability': 'Prescription only',
#   'score': '52.0',
#   'reviews': '841',
#   'description': 'Amoxicillin and clavulanate potassium is a combination prescription antibiotic. Amoxicillin is a penicillin antibiotic that fights bacteria in the body. Clavulanate potassium is a beta-lactamase inhibitor that helps prevent certain bacteria from becoming resistant to amoxicillin.',
#   'side_effects': ['\nsevere stomach pain, diarrhea that is watery bloody (even if it occurs months after your last dose)\n',
#    '\npale yellowed skin, dark colored urine, fever, confusion weakness\n',
#    '\nloss of appetite, upper stomach pain\n',
#    '\nlittle no urination\n',
#    '\neasy bruising bleeding\n'],
#   'drug name': 'Amoxicillin and Clavulanate'},
#  {'interactions_url': '/drug-interactions/ampicillin-index.html',
#   'Generic name': 'ampicillin',
#   'Drug class': ['Aminopenicillins'],
#   'availability': 'Prescription only',
#   'score': '100.0',
#   'reviews': '4',
#   'description': 'Ampicillin is a penicillin antibiotic that is used to treat or prevent many different types of infections such as bladder infections, pneumonia, gonorrhea, meningitis, or infections of the stomach or intestines.',
#   'side_effects': ['\nsevere stomach pain, diarrhea that is watery bloody (even if it occurs months after your last dose)\n',
#    '\nblisters, ulcers, soreness in your mouth\n',
#    '\nskin rash, redness, itching\n',
#    '\nfever, chills, sore throat, swollen glands, joint pain, not feeling well\n',
#    '\npale skin, cold hands and feet\n',
#    '\nfeeling light\n'],
#   'drug name': 'Ampicillin'},
#  {'interactions_url': '/drug-interactions/anastrozole-index.html',
#   'Generic name': 'anastrozole',
#   'Dosage form': 'oral tablet',
#   'availability': 'Prescription only',
#   'score': '51.9',
#   'reviews': '205',
#   'description': 'Anastrozole lowers estrogen levels in postmenopausal women, which may slow the growth of certain types of breast tumors that need estrogen to grow in the body.',
#   'side_effects': ['\nshortness of breath (even with mild exertion), swelling, rapid weight gain\n',
#    '\nnumbness, prickly feeling, pain, weakness in your hands wrists\n',
#    '\nsymptoms of bone fracture\n',
#    '\nliver problems\n',
#    '\nsigns of a stroke\n'],
#   'drug name': 'Anastrozole'},
#  {'interactions_url': '/drug-interactions/testosterone,androgel-index.html',
#   'Generic name': ['testosterone topical'],
#   'Drug class': ['Androgens and anabolic steroids'],
#   'availability': 'Prescription only',
#   'score': '73.8',
#   'reviews': '104',
#   'description': 'AndroGel contains testosterone, a naturally occurring male hormone necessary for many processes in the body. It works by replacing or supplementing the testosterone that is naturally made in the body.',
#   'side_effects': ['\nincreased urination (many times per day), loss of bladder control\n',
#    '\npainful difficult urination\n',
#    '\nbreast pain swelling\n',
#    '\npainful bothersome erections\n',
#    '\nswelling, rapid weight gain, shortness of breath during sleep\n',
#    '\nchest pain pressure, pain spreading to your jaw shoulder\n',
#    '\nliver problems \n',
#    '\nsigns of a blood clot in the lung \n',
#    '\nsigns of a blood clot in your leg \n'],
#   'drug name': 'AndroGel'},
#  {'interactions_url': '/drug-interactions/apalutamide-index.html',
#   'Generic name': 'apalutamide',
#   'Dosage form': 'oral tablet',
#   'availability': 'Prescription only',
#   'score': '80.0',
#   'reviews': '3',
#   'description': 'Apalutamide is an anti-androgen. It works in the body by preventing the actions of androgens (male hormones).',
#   'side_effects': ['\nchest pain discomfort (even while at rest), shortness of breath\n',
#    '\na seizure\n',
#    '\na fall\n',
#    '\nsigns of a stroke \n'],
#   'drug name': 'Apalutamide'},
#  {'interactions_url': '/drug-interactions/apixaban-index.html',
#   'Generic name': 'apixaban',
#   'Dosage form': 'oral tablet',
#   'Drug class': ['Factor Xa inhibitors'],
#   'availability': 'Prescription only',
#   'score': '49.8',
#   'reviews': '232',
#   'description': 'Apixaban is used to lower the risk of stroke caused by a blood clot in people with a heart rhythm disorder called atrial fibrillation.',
#   'side_effects': ['\neasy bruising, unusual bleeding (nose, mouth, vagina, rectum), bleeding from wounds needle injections, any bleeding that will not stop\n',
#    '\nheavy menstrual bleeding\n',
#    '\nheadache, dizziness, weakness, feeling like you might pass out\n',
#    '\nurine that looks red, pink, brown\n',
#    '\nblack bloody stools, coughing up blood vomit that looks like coffee grounds\n'],
#   'drug name': 'Apixaban'},
#  {'interactions_url': '/drug-interactions/apomorphine,apokyn-index.html',
#   'Generic name': ['apomorphine injection'],
#   'Drug class': ['Dopaminergic antiparkinsonism agents'],
#   'availability': 'Prescription only',
#   'score': '73.3',
#   'reviews': '3',
#   'description': "Apokyn has some of the same effects as a chemical called dopamine, which occurs naturally in your body. Low levels of dopamine in the brain are associated with Parkinson's disease.",
#   'side_effects': ['\na light\n',
#    '\nextreme drowsiness, falling asleep suddenly, even after feeling alert\n',
#    '\nconfusion, hallucinations, unusual thoughts behavior\n',
#    '\ntwitching uncontrollable movements of your eyes, lips, tongue, face, arms, legs\n',
#    '\nfast pounding heartbeats, fluttering in your chest, shortness of breath, and sudden dizziness (like you might pass out)\n',
#    '\nongoing nausea vomiting (even after taking anti\n',
#    '\nnew worsening cough, fever, pain when you breathe, feeling short of breath while lying down\n',
#    '\npenis erection that is painful lasts 4 hours longer\n',
#    '\nworsening of your Parkinson symptoms\n',
#    '\npale yellowed skin, dark colored urine, fever, confusion weakness\n',
#    '\nsevere nervous system reaction \n'],
#   'drug name': 'Apokyn'},
#  {'interactions_url': '/drug-interactions/mesalamine,apriso-index.html',
#   'Generic name': ['mesalamine'],
#   'Drug class': '5-aminosalicylates',
#   'availability': 'Prescription only',
#   'score': '66.4',
#   'reviews': '24',
#   'description': 'Apriso affects a substance in the body that causes inflammation, tissue damage, and diarrhea.',
#   'side_effects': ['\nsevere stomach pain, stomach cramping, bloody diarrhea\n',
#    '\nfever, headache, general ill feeling\n',
#    '\nrash, itching, eye redness\n',
#    '\nbloody tarry stools, coughing up blood vomit that looks like coffee grounds\n',
#    '\nlow white blood cell counts \n',
#    '\nsigns of a kidney stone \n',
#    '\nkidney problems \n',
#    '\nliver problems \n'],
#   'drug name': 'Apriso'},
#  {'interactions_url': '/drug-interactions/eslicarbazepine,aptiom-index.html',
#   'Generic name': ['eslicarbazepine'],
#   'Drug class': ['Dibenzazepine anticonvulsants'],
#   'availability': 'Prescription only',
#   'score': '65.8',
#   'reviews': '36',
#   'description': 'Aptiom is an anticonvulsant. It works by decreasing nerve impulses that cause seizures and pain.',
#   'side_effects': ['\nsevere dizziness drowsiness, vision changes, thinking problems, trouble with walking coordination\n',
#    '\nsudden weakness ill feeling, fever, chills, sore throat, mouth sores\n',
#    '\nliver problems \n'],
#   'drug name': 'Aptiom'},
#  {'interactions_url': '/drug-interactions/donepezil,aricept-index.html',
#   'Generic name': ['donepezil'],
#   'Drug class': ['Cholinesterase inhibitors'],
#   'availability': 'Prescription only',
#   'score': '54.5',
#   'reviews': '31',
#   'description': 'Aricept improves the function of nerve cells in the brain. It works by preventing the breakdown of a chemical called acetylcholine (ah SEET il KOE leen). People with dementia usually have lower levels of this chemical, which is important for the processes of memory, thinking, and reasoning.',
#   'side_effects': ['\nsevere ongoing vomiting\n',
#    '\na light\n',
#    '\nslow heartbeats\n',
#    '\nseizure (convulsions)\n',
#    '\npainful difficult urination\n',
#    '\nnew worsening breathing problems\n',
#    '\nsigns of stomach bleeding\n'],
#   'drug name': 'Aricept'},
#  {'interactions_url': '/drug-interactions/anastrozole,arimidex-index.html',
#   'Generic name': ['anastrozole'],
#   'availability': 'Prescription only',
#   'score': '59.0',
#   'reviews': '69',
#   'description': 'Arimidex lowers estrogen levels in postmenopausal women, which may slow the growth of certain types of breast tumors that need estrogen to grow in the body.',
#   'side_effects': ['\nshortness of breath (even with mild exertion), swelling, rapid weight gain\n',
#    '\nnumbness, prickly feeling, pain, weakness in your hands wrists\n',
#    '\nsymptoms of bone fracture \n',
#    '\nliver problems \n',
#    '\nsigns of a stroke \n'],
#   'drug name': 'Arimidex'},
#  {'interactions_url': '/drug-interactions/aripiprazole-index.html',
#   'Generic name': 'aripiprazole',
#   'Drug class': ['Atypical antipsychotics'],
#   'availability': 'Prescription only',
#   'score': '60.0',
#   'reviews': '1',
#   'description': 'Aripiprazole is an antipsychotic medicine that is used to treat schizophrenia in adults and children at least 13 years old.',
#   'side_effects': ['\nsevere agitation, distress, restless feeling\n',
#    '\ntwitching uncontrollable movements of your eyes, lips, tongue, face, arms, legs\n',
#    '\nmask\n',
#    '\nseizure (convulsions)\n',
#    '\nsevere nervous system reaction \n',
#    '\nlow blood cell counts \n',
#    '\nhigh blood sugar \n'],
#   'drug name': 'Aripiprazole'},
#  {'interactions_url': '/drug-interactions/aripiprazole,aristada-index.html',
#   'Generic name': ['aripiprazole'],
#   'Drug class': ['Atypical antipsychotics'],
#   'availability': 'Prescription only',
#   'score': '34.2',
#   'reviews': '12',
#   'description': 'Aristada is an antipsychotic medication. It works by changing the actions of chemicals in the brain.',
#   'side_effects': ['\nuncontrolled muscle movements in your face (chewing, lip smacking, frowning, tongue movement, blinking eye movement)\n',
#    '\nfeeling uncomfortably warm hot\n',
#    '\ntrouble swallowing\n',
#    '\na seizure\n',
#    '\nsevere nervous system reaction \n',
#    '\nlow blood cell counts \n',
#    '\nhigh blood sugar \n'],
#   'drug name': 'Aristada'},
#  {'interactions_url': '/drug-interactions/exemestane,aromasin-index.html',
#   'Generic name': ['exemestane'],
#   'availability': 'Prescription only',
#   'score': '44.7',
#   'reviews': '18',
#   'description': 'Aromasin ) lowers estrogen levels in postmenopausal women, which may slow the growth of certain types of breast tumors that need estrogen to grow in the body.',
#   'side_effects': ['\nchest pain pressure\n',
#    '\nnew unusual bone pain\n',
#    '\nswelling in your hands feet\n',
#    '\nfeeling short of breath, even with mild exertion\n',
#    '\nsigns of a blood clot \n'],
#   'drug name': 'Aromasin'},
#  {'interactions_url': '/drug-interactions/hydroxyzine,atarax-index.html',
#   'Generic name': ['hydroxyzine'],
#   'availability': 'Discontinued',
#   'score': '62.9',
#   'reviews': '140',
#   'description': 'Atarax reduces activity in the central nervous system. It also acts as an antihistamine that reduces the natural chemical histamine in the body. Histamine can produce symptoms of sneezing and runny nose, or hives on the skin.',
#   'side_effects': ['\nrestless muscle movements in your eyes, tongue, jaw, neck\n',
#    '\ntremor (uncontrolled shaking)\n',
#    '\nconfusion\n',
#    '\nseizure (convulsions)\n'],
#   'drug name': 'Atarax'},
#  {'interactions_url': '/drug-interactions/atenolol-index.html',
#   'Generic name': 'atenolol',
#   'Dosage form': 'oral tablet',
#   'Drug class': ['Cardioselective beta blockers'],
#   'availability': 'Prescription only',
#   'score': '73.0',
#   'reviews': '251',
#   'description': 'Atenolol is a beta-blocker that affects the heart and circulation (blood flow through arteries and veins).',
#   'side_effects': ['\nnew worsening chest pain\n',
#    '\nslow uneven heartbeats\n',
#    '\na light\n',
#    '\nshortness of breath (even with mild exertion), swelling, rapid weight gain\n',
#    '\na cold feeling in your hands and feet\n'],
#   'drug name': 'Atenolol'},
#  {'interactions_url': '/drug-interactions/lorazepam,ativan-index.html',
#   'Generic name': ['lorazepam'],
#   'availability': 'Prescription only',
#   'score': '80.0',
#   'reviews': '446',
#   'description': 'Ativan belongs to a group of drugs called benzodiazepines (ben-zoe-dye-AZE-eh-peens). It is thought that lorazepam works by enhancing the activity of certain neurotransmitters in the brain.',
#   'side_effects': ['\nsevere drowsiness\n',
#    '\nunusual changes in mood behavior, being agitated talkative\n',
#    '\nsudden restless feeling excitement\n',
#    '\nthoughts of suicide hurting yourself\n',
#    '\nconfusion, aggression, hallucinations\n',
#    '\nsleep problems\n',
#    '\nvision changes\n',
#    '\ndark urine, jaundice (yellowing of the skin eyes)\n'],
#   'drug name': 'Ativan'},
#  {'interactions_url': '/drug-interactions/atomoxetine-index.html',
#   'Generic name': 'atomoxetine',
#   'Dosage form': 'oral capsule',
#   'Drug class': ['Adrenergic uptake inhibitors for ADHD'],
#   'availability': 'Prescription only',
#   'score': '51.8',
#   'reviews': '562',
#   'description': 'Atomoxetine is used to treat attention deficit hyperactivity disorder (ADHD).',
#   'side_effects': ['\nsigns of heart problems\n',
#    '\nsigns of psychosis\n',
#    '\nliver problems\n',
#    '\npainful difficult urination\n',
#    '\nerection is painful lasts longer than 4 hours (this is a rare side effect)\n'],
#   'drug name': 'Atomoxetine'},
#  {'interactions_url': '/drug-interactions/atorvastatin-index.html',
#   'Generic name': 'atorvastatin',
#   'Dosage form': 'oral tablet',
#   'Drug class': ['Statins'],
#   'availability': 'Prescription only',
#   'score': '42.5',
#   'reviews': '272',
#   'description': 'Atorvastatin belongs to a group of drugs called HMG CoA reductase inhibitors, or "statins."',
#   'side_effects': ['muscle weakness in your hips, shoulders, neck, and back',
#    'trouble lifting your arms, trouble climbing standing',
#    'liver problems',
#    'kidney problems'],
#   'drug name': 'Atorvastatin'},
#  {'interactions_url': '/drug-interactions/teriflunomide,aubagio-index.html',
#   'Generic name': ['teriflunomide'],
#   'Drug class': ['Selective immunosuppressants'],
#   'availability': 'Prescription only',
#   'score': '52.4',
#   'reviews': '78',
#   'description': 'Aubagio affects the immune system and reduces swelling and inflammation in the nervous system.',
#   'side_effects': ['\nnumbness tingling in your hands feet that feels different from your MS symptoms\n',
#    '\ntrouble breathing, new worsening cough with without fever\n',
#    '\nsigns of infection \n',
#    '\nliver problems \n'],
#   'drug name': 'Aubagio'},
#  {'interactions_url': '/drug-interactions/amoxicillin-clavulanate,augmentin-index.html',
#   'Generic name': ['amoxicillin and clavulanate potassium'],
#   'Drug class': 'Beta-lactamase inhibitors',
#   'availability': 'Prescription only',
#   'score': '54.0',
#   'reviews': '413',
#   'description': 'Augmentin contains a combination of amoxicillin and clavulanate potassium. Amoxicillin is a penicillin antibiotic that fights bacteria in the body. Clavulanate potassium is a beta-lactamase inhibitor that helps prevent certain bacteria from becoming resistant to amoxicillin.',
#   'side_effects': ['\nsevere stomach pain, diarrhea that is watery bloody (even if it occurs months after your last dose)\n',
#    '\npale yellowed skin, dark colored urine, fever, confusion weakness\n',
#    '\nloss of appetite, upper stomach pain\n',
#    '\nlittle no urination\n',
#    '\neasy bruising bleeding\n'],
#   'drug name': 'Augmentin'},
#  {'interactions_url': '/drug-interactions/deutetrabenazine,austedo-index.html',
#   'Generic name': ['deutetrabenazine'],
#   'Drug class': ['VMAT2 inhibitors'],
#   'availability': 'Prescription only',
#   'score': '53.3',
#   'reviews': '3',
#   'description': "Austedo reduces the amount of certain chemicals in the body that are overly active in people with Huntington's disease.",
#   'side_effects': ['\nfast pounding heartbeats, fluttering in your chest, shortness of breath, and sudden dizziness (like you might pass out)\n',
#    '\npain burning when you urinate\n',
#    '\nsevere restlessness agitation\n',
#    '\ntremors, shaking\n',
#    '\nmuscle stiffness\n',
#    '\nproblems with balance coordination\n',
#    '\nsevere nervous system reaction \n'],
#   'drug name': 'Austedo'},
#  {'interactions_url': '/drug-interactions/infliximab,avsola-index.html',
#   'Generic name': 'infliximab-axxq',
#   'Dosage form': 'intravenous',
#   'Drug class': ['TNF alfa inhibitors'],
#   'availability': 'Prescription only',
#   'score': '10.0',
#   'reviews': '1',
#   'description': 'Avsola (infliximab-axxq) is a monoclonal antibody drug used to treat certain inflammatory autoimmune diseases. Avsola is a biological drug and one of four biosimilars of Remicade (infliximab). Biosimilars are highly similar versions of a drug that are designed to have the same effect, but they are not identical to the original version of the drug.',
#   'side_effects': ['See "Important information" above',
#    'Serious Infections\n\nSome patients, especially those 65 years and older have had serious infections while receiving infliximab products, such as Avsola These serious infections include TB and infections caused by viruses, fungi, bacteria that have spread throughout the body cause infections in certain areas (such as skin) Some patients die from these infections If you get an infection while receiving treatment with Avsola your doctor will treat your infection and may need to stop your Avsola treatment\nTell your doctor right away if you have any of the following signs of an infection while receiving after receiving Avsola:\n\na fever\nfeel very tired\nhave a cough\nhave flu\nwarm, red, painful skin\n\n\nYour doctor will examine you for TB and perform a test to see if you have TB If your doctor feels that you are at risk for TB, you may be treated with medicine for TB before you begin treatment with Avsola and during treatment with Avsola\nEven if your TB test is negative, your doctor should carefully monitor you for TB infections while you are receiving Avsola Patients who had a negative TB skin test before receiving infliximab products have developed active TB\nIf you are a chronic carrier of the hepatitis B virus, the virus can become active while you are being treated with Avsola In some cases, patients have died as a result of hepatitis B virus being reactivated Your doctor should do a blood test for hepatitis B virus before you start treatment with Avsola and occasionally while you are being treated Tell your doctor if you have any of the following symptoms:\n\nfeel unwell\npoor appetite\ntiredness (fatigue)\nfever, skin rash, joint pain\n\n\n\n',
#    'Some patients, especially those 65 years and older have had serious infections while receiving infliximab products, such as Avsola These serious infections include TB and infections caused by viruses, fungi, bacteria that have spread throughout the body cause infections in certain areas (such as skin) Some patients die from these infections If you get an infection while receiving treatment with Avsola your doctor will treat your infection and may need to stop your Avsola treatment',
#    'Tell your doctor right away if you have any of the following signs of an infection while receiving after receiving Avsola:\n\na fever\nfeel very tired\nhave a cough\nhave flu\nwarm, red, painful skin\n\n',
#    'a fever',
#    'feel very tired',
#    'have a cough',
#    'have flu',
#    'warm, red, painful skin',
#    'Your doctor will examine you for TB and perform a test to see if you have TB If your doctor feels that you are at risk for TB, you may be treated with medicine for TB before you begin treatment with Avsola and during treatment with Avsola',
#    'Even if your TB test is negative, your doctor should carefully monitor you for TB infections while you are receiving Avsola Patients who had a negative TB skin test before receiving infliximab products have developed active TB',
#    'If you are a chronic carrier of the hepatitis B virus, the virus can become active while you are being treated with Avsola In some cases, patients have died as a result of hepatitis B virus being reactivated Your doctor should do a blood test for hepatitis B virus before you start treatment with Avsola and occasionally while you are being treated Tell your doctor if you have any of the following symptoms:\n\nfeel unwell\npoor appetite\ntiredness (fatigue)\nfever, skin rash, joint pain\n\n',
#    'feel unwell',
#    'poor appetite',
#    'tiredness (fatigue)',
#    'fever, skin rash, joint pain',
#    'Heart Failure\nIf you have a heart problem called congestive heart failure, your doctor should check you closely while you are receiving Avsola Your congestive heart failure may get worse while you are receiving Avsola Be sure to tell your doctor of any new worse symptoms including:\n\nshortness of breath\nswelling of ankles feet\nsudden weight gain\nTreatment with Avsola may need to be stopped if you get new worse congestive heart failure\n\n',
#    'shortness of breath',
#    'swelling of ankles feet',
#    'sudden weight gain\nTreatment with Avsola may need to be stopped if you get new worse congestive heart failure',
#    'Other Heart Problems\nSome patients have experienced a heart attack (some of which led to death), low blood flow to the heart, abnormal heart rhythm within 24 hours of beginning their infusion of infliximab products Symptoms may include chest discomfort pain, arm pain, stomach pain, shortness of breath, anxiety, lightheadedness, dizziness, fainting, sweating, nausea, vomiting, fluttering pounding in your chest, and/or a fast a slow heartbeat Tell your doctor right away if you have any of these symptoms',
#    'Liver Injury\nSome patients receiving infliximab products have developed serious liver problems Tell your doctor if you have:\n\njaundice (skin and eyes turning yellow)\ndark brown\npain on the right side of your stomach area (right\nfever\nextreme tiredness (severe fatigue)\n\n',
#    'jaundice (skin and eyes turning yellow)',
#    'dark brown',
#    'pain on the right side of your stomach area (right',
#    'fever',
#    'extreme tiredness (severe fatigue)',
#    'Blood Problems\nIn some patients receiving infliximab products, the body may not make enough of the blood cells that help fight infections help stop bleeding Tell your doctor if you:\n\nhave a fever that does not go away\nbruise bleed very easily\nlook very pale\n\n',
#    'have a fever that does not go away',
#    'bruise bleed very easily',
#    'look very pale',
#    'Nervous System Disorders\nSome patients receiving infliximab products have developed problems with their nervous system Tell your doctor if you have:\n\nchanges in your vision\nweakness in your arms legs\nnumbness tingling in any part of your body\nseizures\n\n',
#    'changes in your vision',
#    'weakness in your arms legs',
#    'numbness tingling in any part of your body',
#    'seizures',
#    'Some patients have experienced a stroke within approximately 24 hours of their infusion with infliximab products Tell your doctor right away if you have symptoms of a stroke which may include: numbness weakness of the face, arm leg, especially on one side of the body sudden confusion, trouble speaking understanding sudden trouble seeing in one both eyes, sudden trouble walking, dizziness, loss of balance coordination a sudden, severe headache',
#    'Allergic Reactions\nSome patients have had allergic reactions to infliximab products Some of these reactions were severe These reactions can happen while you are getting your Avsola treatment shortly afterward Your doctor may need to stop pause your treatment with Avsola and may give you medicines to treat the allergic reaction Signs of an allergic reaction can include:\n\nhives (red, raised, itchy patches of skin)\ndifficulty breathing\nchest pain\nhigh low blood pressure\nfever\nchills\n\nSome patients treated with infliximab products have had delayed allergic reactions The delayed reactions occurred 3 to 12 days after receiving treatment with infliximab products Tell your doctor right away if you have any of these signs of delayed allergic reaction to Avsola:\nfever\nrash\nheadache\nsore throat\nmuscle joint pain\nswelling of the face and hands\ndifficulty swallowing\n\n',
#    'hives (red, raised, itchy patches of skin)',
#    'difficulty breathing',
#    'chest pain',
#    'high low blood pressure',
#    'fever',
#    'chills\n\nSome patients treated with infliximab products have had delayed allergic reactions The delayed reactions occurred 3 to 12 days after receiving treatment with infliximab products Tell your doctor right away if you have any of these signs of delayed allergic reaction to Avsola:',
#    'fever',
#    'rash',
#    'headache',
#    'sore throat',
#    'muscle joint pain',
#    'swelling of the face and hands',
#    'difficulty swallowing',
# ...
#   'availability': 'Prescription only',
#   'score': '45.3',
#   'reviews': '39',
#   'description': 'Zometa is a bisphosphonate medicine that alters bone formation and breakdown in the body. This can slow bone loss and may help prevent bone fractures.',
#   'side_effects': ['\nnew unusual pain in your thigh hip\n',
#    '\njaw pain numbness, red swollen gums, loose teeth, slow healing after dental work\n',
#    '\nsevere joint, bone, muscle pain\n',
#    '\nkidney problems \n',
#    '\nlow red blood cells (anemia) \n',
#    '\nlow calcium levels \n'],
#   'drug name': 'Zometa'},
#  {'interactions_url': '/drug-interactions/zolmitriptan,zomig-index.html',
#   'Generic name': ['zolmitriptan'],
#   'Drug class': ['Antimigraine agents'],
#   'availability': 'Prescription only',
#   'score': '69.5',
#   'reviews': '95',
#   'description': 'Zomig is a headache medicine that narrows blood vessels around the brain. Zolmitriptan also reduces substances in the body that can trigger headache pain, nausea, sensitivity to light and sound, and other migraine symptoms.',
#   'side_effects': ['\nfeeling of tightness in your jaw, neck, throat, chest\n',
#    '\nfast pounding heartbeats, dizziness\n',
#    '\nsudden and severe stomach pain and bloody diarrhea\n',
#    '\nheart attack symptoms \n',
#    '\nhigh levels of serotonin in the body \n'],
#   'drug name': 'Zomig'},
#  {'interactions_url': '/drug-interactions/zonisamide,zonegran-index.html',
#   'Generic name': ['zonisamide'],
#   'Drug class': ['Carbonic anhydrase inhibitor anticonvulsants'],
#   'availability': 'Prescription only',
#   'score': '65.8',
#   'reviews': '63',
#   'description': 'Zonegran is a sulfa drug with anti-convulsant effects.',
#   'side_effects': ['\neye pain redness any changes in your vision\n',
#    '\ndecreased sweating, feeling very hot\n',
#    '\nsigns of metabolic acidosis \n',
#    '\nsymptoms of a blood cell disorder \n',
#    '\nsymptoms of a kidney stone \n',
#    '\nincreased worsening seizures\n',
#    '\nthe first sign of any skin rash, no matter how mild\n',
#    '\nsevere skin reaction \n'],
#   'drug name': 'Zonegran'},
#  {'interactions_url': '/drug-interactions/zonisamide-index.html',
#   'Generic name': 'zonisamide',
#   'Dosage form': 'oral capsule',
#   'Drug class': ['Carbonic anhydrase inhibitor anticonvulsants'],
#   'availability': 'Prescription only',
#   'score': '54.8',
#   'reviews': '138',
#   'description': 'Zonisamide is used together with other medicines to treat partial seizures in adults and teenagers at least 16 years old.',
#   'side_effects': ['\neye pain redness any changes in your vision\n',
#    '\ndecreased sweating, feeling very hot\n',
#    '\nsigns of metabolic acidosis\n',
#    '\nsymptoms of a blood cell disorder\n',
#    '\nsymptoms of a kidney stone\n',
#    '\nincreased worsening seizures\n',
#    '\nthe first sign of any skin rash, no matter how mild\n',
#    '\nsevere skin reaction\n'],
#   'drug name': 'Zonisamide'},
#  {'interactions_url': '/drug-interactions/piperacillin-tazobactam,zosyn-index.html',
#   'Generic name': ['piperacillin and tazobactam'],
#   'Drug class': 'Beta-lactamase inhibitors',
#   'availability': 'Prescription only',
#   'score': '86.7',
#   'reviews': '5',
#   'description': 'Zosyn contains a combination of piperacillin and tazobactam. Piperacillin and tazobactam are penicillin antibiotics that fight bacteria in the body.',
#   'side_effects': ['\nsevere stomach pain, diarrhea that is watery bloody (even if it occurs months after your last dose)\n',
#    '\nconfusion\n',
#    '\nmuscle twitching stiffness, trouble walking\n',
#    '\na seizure\n',
#    '\nlow white blood cell counts: may experience fever, mouth sores, skin sores, sore throat, cough, trouble breathing\n',
#    '\nlow potassium: may experience leg cramps, constipation, irregular heartbeats, fluttering in your chest, increased thirst urination, numbness tingling, muscle weakness limp feeling\n'],
#   'drug name': 'Zosyn'},
#  {'interactions_url': '/drug-interactions/acyclovir,zovirax-index.html',
#   'Generic name': ['acyclovir'],
#   'Drug class': ['Purine nucleosides'],
#   'availability': 'Prescription only',
#   'score': '82.4',
#   'reviews': '17',
#   'description': 'Zovirax is an antiviral drug. Acyclovir slows the growth and spread of the herpes virus in the body.',
#   'side_effects': ['\neasy bruising bleeding, purple red pinpoint spots under your skin\n',
#    '\nchanges in behavior\n',
#    '\nconfusion, hallucinations\n',
#    '\nsigns of a kidney problem \n'],
#   'drug name': 'Zovirax'},
#  {'interactions_url': '/drug-interactions/idelalisib,zydelig-index.html',
#   'Generic name': ['idelalisib'],
#   'Drug class': ['PI3K inhibitors'],
#   'availability': 'Prescription only',
#   'score': '10.0',
#   'reviews': '1',
#   'description': 'Zydelig is a cancer medication that interferes with the growth and spread of cancer cells in the body.',
#   'side_effects': ['\nsevere diarrhea, increased number of stools per day\n',
#    '\neasy bruising, unusual bleeding, purple red spots under your skin\n',
#    '\nintestinal problems \n',
#    '\nliver problems \n',
#    '\nlung problems \n',
#    '\nlow white blood cell counts \n'],
#   'drug name': 'Zydelig'},
#  {'interactions_url': '/drug-interactions/ceritinib,zykadia-index.html',
#   'Generic name': ['ceritinib'],
#   'Drug class': ['Multikinase inhibitors'],
#   'availability': 'Prescription only',
#   'score': None,
#   'reviews': None,
#   'description': 'Zykadia is a cancer medicine that interferes with the growth and spread of cancer cells in the body.',
#   'side_effects': ['\nsevere pain in your upper stomach spreading to your back\n',
#    '\nslow heartbeats, weak pulse, weak shallow breathing\n',
#    '\nsudden chest pain discomfort, fever, dry cough cough with mucus, feeling short of breath\n',
#    '\nfast pounding heartbeats, fluttering in your chest, shortness of breath, and sudden dizziness (like you might pass out)\n',
#    '\nhigh blood sugar \n',
#    '\nhigh blood sugar \n',
#    '\nliver problems \n'],
#   'drug name': 'Zykadia'},
#  {'interactions_url': '/drug-interactions/allopurinol,zyloprim-index.html',
#   'Generic name': ['allopurinol'],
#   'availability': 'Prescription only',
#   'score': '90.0',
#   'reviews': '1',
#   'description': 'Allopurinol is used to prevent or lower high uric acid levels in the blood. It is also used to prevent or lower excess uric acid levels caused by cancer medicines or in patients with kidney stones. A high uric acid level can cause gout or gouty arthritis (joint pain and inflammation). Allopurinol is a xanthine oxidase inhibitor that works by decreasing the uric acid produced by the body.',
#   'side_effects': ['Ankle, knee, great toe joint pain',
#    'joint stiffness swelling',
#    'rash',
#    'rash with flat lesions small raised lesions on the skin'],
#   'drug name': 'Zyloprim'},
#  {'interactions_url': '/drug-interactions/olanzapine,zyprexa-index.html',
#   'Generic name': ['olanzapine'],
#   'Drug class': ['Atypical antipsychotics'],
#   'availability': 'Prescription only',
#   'score': '58.7',
#   'reviews': '321',
#   'description': 'Zyprexa is an antipsychotic medication that affects chemicals in the brain.',
#   'side_effects': ['\nuncontrolled muscle movements in your face (chewing, lip smacking, frowning, tongue movement, blinking eye movement)\n',
#    '\ntrouble speaking swallowing\n',
#    '\nswelling in your hands feet\n',
#    '\nconfusion, unusual thoughts behavior, hallucinations, thoughts about hurting yourself\n',
#    '\nlow white blood cell counts \n',
#    '\nsigns of dehydration \n',
#    '\nliver problems \n',
#    '\nhigh blood sugar \n',
#    '\nsevere nervous system reaction \n'],
#   'drug name': 'Zyprexa'},
#  {'interactions_url': '/drug-interactions/cetirizine,zyrtec-index.html',
#   'Generic name': ['cetirizine'],
#   'Drug class': ['Antihistamines'],
#   'availability': 'Rx and/or OTC',
#   'score': '57.9',
#   'reviews': '185',
#   'description': 'Zyrtec is an antihistamine that reduces the effects of natural chemical histamine in the body. Histamine can produce symptoms of sneezing, itching, watery eyes, and runny nose.',
#   'side_effects': ['\nfast, pounding, uneven heartbeat\n',
#    '\nweakness, tremors (uncontrolled shaking), sleep problems (insomnia)\n',
#    '\nsevere restless feeling, hyperactivity\n',
#    '\nconfusion\n',
#    '\nproblems with vision\n',
#    '\nlittle no urination\n'],
#   'drug name': 'Zyrtec'},
#  {'interactions_url': '/drug-interactions/cetirizine-pseudoephedrine,zyrtec-d-index.html',
#   'Generic name': ['cetirizine and pseudoephedrine'],
#   'Drug class': ['Upper respiratory combinations'],
#   'availability': 'Rx and/or OTC',
#   'score': '92.5',
#   'reviews': '3',
#   'description': 'Cetirizine is an antihistamine that reduces the natural chemical histamine in the body. Histamine can produce symptoms of sneezing, itching, watery eyes, and runny nose.',
#   'side_effects': ['\nfast, pounding, uneven heartbeat\n',
#    '\nweakness, tremors (uncontrolled shaking)\n',
#    '\nsevere restless feeling, hyperactivity, extreme feeling of fear confusion\n',
#    '\nproblems with vision\n',
#    '\nlittle no urinating\n',
#    '\nhigh blood pressure (severe headache, buzzing in your ears, chest pain, shortness of breath, uneven heartbeats)\n'],
#   'drug name': 'Zyrtec-D'},
#  {'interactions_url': '/drug-interactions/abiraterone,zytiga-index.html',
#   'Generic name': ['abiraterone'],
#   'Drug class': ['Miscellaneous antineoplastics'],
#   'availability': 'Prescription only',
#   'score': '85.5',
#   'reviews': '37',
#   'description': 'Zytiga works by reducing androgen production in the body. Androgens are male hormones that can promote tumor growth in the prostate gland.',
#   'side_effects': ['\nswelling in your ankles feet, pain in your legs\n',
#    '\nfast irregular heartbeats\n',
#    '\na light\n',
#    '\nsevere headache, blurred vision, pounding in your neck ears\n',
#    '\npain burning when you urinate\n',
#    '\nlow red blood cells (anemia)\n',
#    '\nlow blood potassium\n',
#    '\nliver problems\n',
#    '\nsevere low blood sugar\n'],
#   'drug name': 'Zytiga'},
#  {'interactions_url': '/drug-interactions/linezolid,zyvox-index.html',
#   'Generic name': ['linezolid'],
#   'Drug class': ['Oxazolidinone antibiotics'],
#   'availability': 'Prescription only',
#   'score': '88.1',
#   'reviews': '27',
#   'description': 'Zyvox is an oxazolidinone antibiotic that fights bacteria in the body. Linezolid is also an MAO (monoamine oxidase) inhibitor.',
#   'side_effects': ['\nvision problems, changes in color vision\n',
#    '\nsevere stomach pain, diarrhea that is watery bloody\n',
#    '\na seizure\n',
#    '\nsweating, feeling anxious shaky (may be signs of low blood sugar)\n',
#    '\nhigh levels of serotonin in the body \n',
#    '\nlactic acidosis \n',
#    '\nlow blood cell counts \n'],
#   'drug name': 'Zyvox'},
#  {'interactions_url': '/drug-interactions/pseudoephedrine-index.html',
#   'Generic name': 'pseudoephedrine',
#   'Drug class': ['Decongestants'],
#   'availability': 'Rx and/or OTC',
#   'score': '65.9',
#   'reviews': '77',
#   'description': 'Pseudoephedrine is used to relieve nasal or sinus congestion caused by the common cold, sinusitis, and hay fever and other respiratory allergies. It is also used to relieve ear congestion caused by ear inflammation or infection.',
#   'side_effects': ['Convulsions (seizures)',
#    'hallucinations (seeing, hearing, feeling things that are not there)',
#    'irregular slow heartbeat',
#    'shortness of breath troubled breathing'],
#   'drug name': '12 Hour Cold Maximum Strength'},
#  {'interactions_url': '/drug-interactions/povidone-iodine-topical,3m-skin-and-nasal-antiseptic-index.html',
#   'Generic name': ['povidone iodine topical'],
#   'Drug class': ['Antiseptic and germicides'],
#   'availability': 'Rx and/or OTC',
#   'score': None,
#   'reviews': None,
#   'description': 'There are many brands and forms of povidone iodine topical available. Not all brands are listed on this leaflet.',
#   'side_effects': ['\nswelling, pain, warmth, redness, oozing, other signs of infection\n',
#    '\nblistering crusting\n',
#    '\nsevere irritation, itching, burning\n'],
#   'drug name': '3M Skin and Nasal Antiseptic'},
#  {'interactions_url': '/drug-interactions/lamivudine-index.html',
#   'Generic name': 'lamivudine',
#   'Drug class': 'Nucleoside reverse transcriptase inhibitors',
#   'availability': 'Prescription only',
#   'score': '72.0',
#   'reviews': '5',
#   'description': 'Lamivudine is used in combination with other medicines for the treatment of the infection caused by the human immunodeficiency virus (HIV). HIV is the virus that causes acquired immune deficiency syndrome (AIDS).',
#   'side_effects': ['Black, tarry stools',
#    'bleeding gums',
#    'bloating',
#    'blood in the urine stools',
#    'blurred vision',
#    'chills',
#    'constipation',
#    'cough',
#    'dark urine',
#    'decreased appetite',
#    'diarrhea',
#    'difficulty with swallowing',
#    'dizziness',
#    'dry mouth',
#    'fast heartbeat',
#    'fast, shallow breathing',
#    'fever',
#    'flushed, dry skin',
#    'fruit',
#    'general feeling of discomfort',
#    'general tiredness and weakness',
#    'increased hunger',
#    'increased thirst',
#    'increased urination',
#    'indigestion',
#    'light',
#    'loss of appetite',
#    'muscle cramps, pain, stiffness, spasms',
#    'nausea',
#    'pains in the stomach, side, abdomen, possibly radiating to the back',
#    'pinpoint red spots on the skin',
#    'puffiness swelling of the eyelids around the eyes, face, lips, tongue',
#    'right upper abdominal stomach pain and fullness',
#    'skin rash, hives, itching',
#    'sleepiness',
#    'stomach discomfort',
#    'tightness in the chest',
#    'troubled breathing with exertion',
#    'unexplained weight loss',
#    'unusual bleeding bruising',
#    'unusual tiredness weakness',
#    'upper right abdominal stomach pain',
#    'vomiting',
#    'yellow eyes skin'],
#   'drug name': '3tc'},
#  {'interactions_url': '/drug-interactions/phenylephrine-nasal,4-way-fast-acting-nasal-spray-index.html',
#   'Generic name': ['phenylephrine nasal'],
#   'Drug class': ['Nasal antihistamines and decongestants'],
#   'availability': 'Over the counter',
#   'score': None,
#   'reviews': None,
#   'description': 'Phenylephrine is a decongestant that shrinks blood vessels in the nasal passages. Dilated blood vessels can cause nasal congestion (stuffy nose).',
#   'side_effects': ['\nsevere sneezing, runny stuffy nose, redness swelling in your nose, other worsening nasal symptoms (may be a sign of overuse of 4\n',
#    '\nsevere stinging, burning, irritation inside your nose\n',
#    '\nsevere dizziness, restless feeling, nervousness, insomnia\n',
#    '\nmood changes, unusual thoughts behavior\n',
#    '\ntremors shaking\n',
#    '\nlittle no urination\n'],
#   'drug name': '4-Way'},
#  {'interactions_url': '/drug-interactions/oxymetazoline-nasal,four-way-nasal-spray-index.html',
#   'Generic name': ['oxymetazoline'],
#   'Drug class': ['Nasal antihistamines and decongestants'],
#   'availability': 'Over the counter',
#   'score': None,
#   'reviews': None,
#   'description': 'Oxymetazoline is used for the temporary relief of nasal (of the nose) congestion or stuffiness caused by hay fever or other allergies, colds, or sinus trouble.',
#   'side_effects': ['Blurred vision',
#    'fast, irregular, pounding heartbeat',
#    'headache, dizziness, drowsiness, lightheadedness',
#    'high blood pressure',
#    'increase in runny stuffy nose',
#    'nervousness',
#    'trembling',
#    'trouble in sleeping',
#    'weakness'],
#   'drug name': '4-Way Long Lasting'},
#  {'interactions_url': '/drug-interactions/methoxsalen,8-mop-index.html',
#   'Generic name': ['methoxsalen'],
#   'Drug class': ['Psoralens'],
#   'availability': 'Discontinued',
#   'score': None,
#   'reviews': None,
#   'description': "8-Mop works by enhancing the body's sensitivity to ultraviolet light A (UVA).",
#   'side_effects': ['\nsevere skin redness within 24 hours after UVA treatment\n',
#    '\nswelling, severe itching, severe skin discomfort\n',
#    '\nskin redness and swelling with blisters\n',
#    '\nworsening of your psoriasis\n',
#    '\na new skin lesion, a mole that has changed in size color\n',
#    '\nblurred vision, tunnel vision, eye pain swelling, seeing halos around lights\n'],
#   'drug name': '8-Mop'}]

# %%
len(scraped_drugs)
# Out:
# 910

# %%
diseases_interactions_list_with_key = []
for i in range(len(scraped_drugs)):
    temp = {}
    temp['drug name'] = scraped_drugs[i]
    temp['diseases_interactions'] = diseases_interactions_list[i]
    diseases_interactions_list_with_key.append(temp)

# %%
with open('data/diseases_interactions.json','w') as fp:
    json.dump(diseases_interactions_list_with_key,fp)

# %%
drug_interactions_list_with_key = []
for i in range(len(scraped_drugs)):
    temp = {}
    temp['drug name'] = scraped_drugs[i]
    temp['drug_interactions'] = drug_interactions_list[i]
    drug_interactions_list_with_key.append(temp)

# %%
with open('data/drug_interactions.json','w') as fp:
    json.dump(drug_interactions_list_with_key,fp)

# %%
drug_interactions_list_with_key[0]
# Out:
# {'drug name': 'Abilify',
#  'drug_interactions': [{'class': 'Moderate',
#    'name': 'abametapir topical',
#    'parent_id': '233-109',
#    'id': '4171-0'},
#   {'class': 'Moderate',
#    'name': 'abarelix',
#    'parent_id': '233-109',
#    'id': '5-0'},
#   {'class': 'Moderate',
#    'name': 'abiraterone',
#    'parent_id': '3321-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'acarbose',
#    'parent_id': '9-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'acebutolol',
#    'parent_id': '10-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'acetohexamide',
#    'parent_id': '93-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'acetylcarbromal',
#    'parent_id': '95-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'acetylcholine ophthalmic',
#    'parent_id': '96-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'aclidinium',
#    'parent_id': '3406-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'acrivastine',
#    'parent_id': '2875-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'albiglutide',
#    'parent_id': '3524-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'albuterol',
#    'parent_id': '109-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'alfentanil',
#    'parent_id': '118-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'alfuzosin',
#    'parent_id': '119-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'alogliptin',
#    'parent_id': '3448-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'alprazolam',
#    'parent_id': '133-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amantadine',
#    'parent_id': '148-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amifampridine',
#    'parent_id': '3982-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amiloride',
#    'parent_id': '154-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'aminoglutethimide',
#    'parent_id': '158-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amiodarone',
#    'parent_id': '167-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amisulpride',
#    'parent_id': '4134-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amitriptyline',
#    'parent_id': '168-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amlodipine',
#    'parent_id': '172-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amobarbital',
#    'parent_id': '184-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amoxapine',
#    'parent_id': '186-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amprenavir',
#    'parent_id': '199-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'amyl nitrite',
#    'parent_id': '200-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'anagrelide',
#    'parent_id': '204-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'apalutamide',
#    'parent_id': '3893-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'apomorphine',
#    'parent_id': '224-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'apraclonidine ophthalmic',
#    'parent_id': '225-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'aprepitant',
#    'parent_id': '226-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'arformoterol',
#    'parent_id': '230-0',
#    'id': '233-109'},
#   {'class': 'Minor',
#    'name': 'armodafinil',
#    'parent_id': '234-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'arsenic trioxide',
#    'parent_id': '236-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'asciminib',
#    'parent_id': '4307-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'asenapine',
#    'parent_id': '3168-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'astemizole',
#    'parent_id': '271-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'atazanavir',
#    'parent_id': '272-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'atenolol',
#    'parent_id': '273-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'atomoxetine',
#    'parent_id': '275-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'atropine',
#    'parent_id': '280-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'avacopan',
#    'parent_id': '4305-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'azatadine',
#    'parent_id': '294-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'azelastine nasal',
#    'parent_id': '298-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'azilsartan medoxomil',
#    'parent_id': '3302-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'azithromycin',
#    'parent_id': '300-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'baclofen',
#    'parent_id': '318-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bedaquiline',
#    'parent_id': '3439-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'belladonna',
#    'parent_id': '327-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'belzutifan',
#    'parent_id': '4289-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'benazepril',
#    'parent_id': '332-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bendroflumethiazide',
#    'parent_id': '334-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'benzthiazide',
#    'parent_id': '362-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'benztropine',
#    'parent_id': '363-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bepridil',
#    'parent_id': '366-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'berotralstat',
#    'parent_id': '4224-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'betaxolol',
#    'parent_id': '374-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bexarotene',
#    'parent_id': '378-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bicalutamide',
#    'parent_id': '380-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'biperiden',
#    'parent_id': '384-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bisoprolol',
#    'parent_id': '393-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bitolterol',
#    'parent_id': '395-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'boceprevir',
#    'parent_id': '3323-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bosentan',
#    'parent_id': '403-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bosutinib',
#    'parent_id': '3416-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'brexanolone',
#    'parent_id': '3999-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'brexpiprazole',
#    'parent_id': '3639-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'brimonidine ophthalmic',
#    'parent_id': '410-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'brimonidine topical',
#    'parent_id': '3487-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'brivaracetam',
#    'parent_id': '3728-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bromocriptine',
#    'parent_id': '414-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'brompheniramine',
#    'parent_id': '416-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'bumetanide',
#    'parent_id': '433-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'buprenorphine',
#    'parent_id': '438-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'bupropion',
#    'parent_id': '440-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'buspirone',
#    'parent_id': '441-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'butabarbital',
#    'parent_id': '443-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'butalbital',
#    'parent_id': '2338-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'butorphanol',
#    'parent_id': '448-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cabergoline',
#    'parent_id': '449-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cabozantinib',
#    'parent_id': '3430-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'canagliflozin',
#    'parent_id': '3465-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'candesartan',
#    'parent_id': '487-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cannabidiol',
#    'parent_id': '3919-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cannabis',
#    'parent_id': '2758-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'captopril',
#    'parent_id': '493-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'carbachol ophthalmic',
#    'parent_id': '496-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'carbamazepine',
#    'parent_id': '497-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'carbetapentane',
#    'parent_id': '2804-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'carbinoxamine',
#    'parent_id': '516-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cariprazine',
#    'parent_id': '3684-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'carisoprodol',
#    'parent_id': '527-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'carteolol',
#    'parent_id': '529-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'carvedilol',
#    'parent_id': '531-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'celecoxib',
#    'parent_id': '560-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cenobamate',
#    'parent_id': '4105-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ceritinib',
#    'parent_id': '3527-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cetirizine',
#    'parent_id': '569-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlophedianol',
#    'parent_id': '3182-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chloral hydrate',
#    'parent_id': '577-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chloramphenicol',
#    'parent_id': '579-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorcyclizine',
#    'parent_id': '3268-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlordiazepoxide',
#    'parent_id': '585-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlormezanone',
#    'parent_id': '589-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chloroquine',
#    'parent_id': '593-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorothiazide',
#    'parent_id': '594-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorphenesin',
#    'parent_id': '603-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorpheniramine',
#    'parent_id': '604-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorpromazine',
#    'parent_id': '639-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorpropamide',
#    'parent_id': '640-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorthalidone',
#    'parent_id': '642-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'chlorzoxazone',
#    'parent_id': '645-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cilostazol',
#    'parent_id': '668-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cimetidine',
#    'parent_id': '669-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cinacalcet',
#    'parent_id': '670-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ciprofloxacin',
#    'parent_id': '672-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cisapride',
#    'parent_id': '676-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'citalopram',
#    'parent_id': '679-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clarithromycin',
#    'parent_id': '685-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clemastine',
#    'parent_id': '687-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clevidipine',
#    'parent_id': '2909-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clidinium',
#    'parent_id': '689-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clobazam',
#    'parent_id': '3350-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clofazimine',
#    'parent_id': '699-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clomipramine',
#    'parent_id': '702-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clonazepam',
#    'parent_id': '703-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clonidine',
#    'parent_id': '704-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clorazepate',
#    'parent_id': '706-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'clotrimazole',
#    'parent_id': '3106-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'clozapine',
#    'parent_id': '709-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cobicistat',
#    'parent_id': '3565-0',
#    'id': '233-109'},
#   {'class': 'Major', 'name': 'codeine', 'parent_id': '718-0', 'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'conivaptan',
#    'parent_id': '737-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'crizotinib',
#    'parent_id': '3342-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cyclandelate',
#    'parent_id': '756-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cyclizine',
#    'parent_id': '757-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cyclobenzaprine',
#    'parent_id': '758-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cyclosporine',
#    'parent_id': '763-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'cyproheptadine',
#    'parent_id': '765-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dabrafenib',
#    'parent_id': '3475-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dacomitinib',
#    'parent_id': '3962-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'danazol',
#    'parent_id': '778-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dantrolene',
#    'parent_id': '779-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dapagliflozin',
#    'parent_id': '3506-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'daridorexant',
#    'parent_id': '4332-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'darifenacin',
#    'parent_id': '785-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'darunavir',
#    'parent_id': '786-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dasatinib',
#    'parent_id': '787-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'daunorubicin',
#    'parent_id': '788-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'daunorubicin liposomal',
#    'parent_id': '789-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'deferasirox',
#    'parent_id': '791-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'degarelix',
#    'parent_id': '3102-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'delavirdine',
#    'parent_id': '794-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'demecarium bromide ophthalmic',
#    'parent_id': '795-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'deserpidine',
#    'parent_id': '798-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'desipramine',
#    'parent_id': '802-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'desvenlafaxine',
#    'parent_id': '2796-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'deutetrabenazine',
#    'parent_id': '3799-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dexamethasone',
#    'parent_id': '810-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dexbrompheniramine',
#    'parent_id': '3387-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dexchlorpheniramine',
#    'parent_id': '824-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dexfenfluramine',
#    'parent_id': '834-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dexmedetomidine',
#    'parent_id': '835-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dextromethorphan',
#    'parent_id': '844-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'dezocine',
#    'parent_id': '859-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'diazepam',
#    'parent_id': '862-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'diazoxide',
#    'parent_id': '863-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dicyclomine',
#    'parent_id': '875-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'difelikefalin',
#    'parent_id': '4293-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'diltiazem',
#    'parent_id': '890-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dimenhydrinate',
#    'parent_id': '892-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'diphenhydramine',
#    'parent_id': '896-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'disopyramide',
#    'parent_id': '916-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'divalproex sodium',
#    'parent_id': '918-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dofetilide',
#    'parent_id': '925-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dolasetron',
#    'parent_id': '926-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'donepezil',
#    'parent_id': '927-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dopamine',
#    'parent_id': '928-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'doxazosin',
#    'parent_id': '934-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'doxepin',
#    'parent_id': '935-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'doxepin topical',
#    'parent_id': '936-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'doxorubicin',
#    'parent_id': '938-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'doxorubicin liposomal',
#    'parent_id': '939-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'doxylamine',
#    'parent_id': '942-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dronabinol',
#    'parent_id': '943-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dronedarone',
#    'parent_id': '3147-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'droperidol',
#    'parent_id': '944-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'dulaglutide',
#    'parent_id': '3562-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'duloxetine',
#    'parent_id': '949-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'duvelisib',
#    'parent_id': '3961-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'echinacea',
#    'parent_id': '955-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'echothiophate iodide ophthalmic',
#    'parent_id': '956-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'efavirenz',
#    'parent_id': '963-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'elagolix',
#    'parent_id': '3930-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'eliglustat',
#    'parent_id': '3556-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'eluxadoline',
#    'parent_id': '3630-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'empagliflozin',
#    'parent_id': '3548-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'enalapril',
#    'parent_id': '972-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'enalaprilat',
#    'parent_id': '2367-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'encorafenib',
#    'parent_id': '3921-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'entacapone',
#    'parent_id': '979-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'entrectinib',
#    'parent_id': '4082-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'enzalutamide',
#    'parent_id': '3414-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'epinephrine',
#    'parent_id': '989-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'epirubicin',
#    'parent_id': '996-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'eplerenone',
#    'parent_id': '997-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'eprosartan',
#    'parent_id': '1000-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'eribulin',
#    'parent_id': '3284-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ertugliflozin',
#    'parent_id': '3883-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'erythromycin',
#    'parent_id': '1009-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'escitalopram',
#    'parent_id': '1013-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'esketamine',
#    'parent_id': '3996-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'eslicarbazepine',
#    'parent_id': '3499-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'esmolol',
#    'parent_id': '1014-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'estazolam',
#    'parent_id': '1016-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'eszopiclone',
#    'parent_id': '1030-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ethacrynic acid',
#    'parent_id': '1032-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ethanol',
#    'parent_id': '1034-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ethaverine',
#    'parent_id': '1037-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ethchlorvynol',
#    'parent_id': '1038-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ethosuximide',
#    'parent_id': '1049-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ethotoin',
#    'parent_id': '1050-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'etravirine',
#    'parent_id': '2793-0',
#    'id': '233-109'},
#   {'class': 'Minor',
#    'name': 'evening primrose',
#    'parent_id': '1059-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'exenatide',
#    'parent_id': '1061-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ezogabine',
#    'parent_id': '3330-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'famotidine',
#    'parent_id': '1066-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fedratinib',
#    'parent_id': '4083-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'felbamate',
#    'parent_id': '1068-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'felodipine',
#    'parent_id': '1069-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fenfluramine',
#    'parent_id': '1070-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fenoldopam',
#    'parent_id': '1072-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'fentanyl',
#    'parent_id': '1074-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fesoterodine',
#    'parent_id': '2962-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fexinidazole',
#    'parent_id': '4280-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fingolimod',
#    'parent_id': '3264-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'flavoxate',
#    'parent_id': '1092-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'flecainide',
#    'parent_id': '1094-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'flibanserin',
#    'parent_id': '3675-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fluconazole',
#    'parent_id': '1096-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fluoxetine',
#    'parent_id': '1115-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fluphenazine',
#    'parent_id': '1118-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'flurazepam',
#    'parent_id': '1120-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'flutamide',
#    'parent_id': '1123-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fluvoxamine',
#    'parent_id': '1128-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'formoterol',
#    'parent_id': '1136-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fosamprenavir',
#    'parent_id': '1137-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fosaprepitant',
#    'parent_id': '2862-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'foscarnet',
#    'parent_id': '1138-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fosinopril',
#    'parent_id': '1140-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fosphenytoin',
#    'parent_id': '1142-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fostamatinib',
#    'parent_id': '3908-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'fostemsavir',
#    'parent_id': '4166-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'furosemide',
#    'parent_id': '1146-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'gabapentin',
#    'parent_id': '1147-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'gabapentin enacarbil',
#    'parent_id': '3488-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'galantamine',
#    'parent_id': '1153-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ganaxolone',
#    'parent_id': '4348-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'gatifloxacin',
#    'parent_id': '1161-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'gefitinib',
#    'parent_id': '1163-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'gemifloxacin',
#    'parent_id': '1166-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'gilteritinib',
#    'parent_id': '3981-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ginkgo',
#    'parent_id': '1174-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'givosiran',
#    'parent_id': '4104-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'glasdegib',
#    'parent_id': '3979-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'glimepiride',
#    'parent_id': '1176-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'glipizide',
#    'parent_id': '1179-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'glyburide',
#    'parent_id': '1185-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'glycerol phenylbutyrate',
#    'parent_id': '3452-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'glycopyrrolate',
#    'parent_id': '1192-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'glycopyrronium topical',
#    'parent_id': '3923-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'goldenseal',
#    'parent_id': '2508-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'goserelin',
#    'parent_id': '1195-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'granisetron',
#    'parent_id': '1197-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'grepafloxacin',
#    'parent_id': '1198-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'griseofulvin',
#    'parent_id': '1199-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'guanabenz',
#    'parent_id': '1215-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'guanadrel',
#    'parent_id': '1216-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'guanethidine',
#    'parent_id': '1217-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'guanfacine',
#    'parent_id': '1219-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'halazepam',
#    'parent_id': '1226-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'halofantrine',
#    'parent_id': '1229-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'haloperidol',
#    'parent_id': '1230-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'halothane',
#    'parent_id': '1232-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'heroin',
#    'parent_id': '2759-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'histrelin',
#    'parent_id': '1246-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'hydralazine',
#    'parent_id': '1253-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'hydrochlorothiazide',
#    'parent_id': '1257-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'hydrocodone',
#    'parent_id': '2874-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'hydroflumethiazide',
#    'parent_id': '1291-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'hydromorphone',
#    'parent_id': '1294-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'hydroxychloroquine',
#    'parent_id': '1298-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'hydroxyzine',
#    'parent_id': '1303-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'hyoscyamine',
#    'parent_id': '2513-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ibutilide',
#    'parent_id': '1313-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'idarubicin',
#    'parent_id': '1315-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'idelalisib',
#    'parent_id': '3546-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ifosfamide',
#    'parent_id': '1318-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'iloperidone',
#    'parent_id': '3140-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'imatinib',
#    'parent_id': '1321-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'imipramine',
#    'parent_id': '1323-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'indacaterol',
#    'parent_id': '3333-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'indapamide',
#    'parent_id': '1327-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'indinavir',
#    'parent_id': '1329-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'inotuzumab ozogamicin',
#    'parent_id': '3857-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin',
#    'parent_id': '1340-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin aspart',
#    'parent_id': '1341-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin aspart protamine',
#    'parent_id': '2341-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin degludec',
#    'parent_id': '3693-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin detemir',
#    'parent_id': '1343-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin glargine',
#    'parent_id': '1344-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin glulisine',
#    'parent_id': '1345-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin inhalation, rapid acting',
#    'parent_id': '1346-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin isophane',
#    'parent_id': '1347-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin lispro',
#    'parent_id': '1349-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin lispro protamine',
#    'parent_id': '2766-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin regular',
#    'parent_id': '1351-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin zinc',
#    'parent_id': '1352-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'insulin zinc extended',
#    'parent_id': '1353-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ioflupane I 123',
#    'parent_id': '3297-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'iohexol',
#    'parent_id': '1372-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'iopamidol',
#    'parent_id': '1373-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ipratropium',
#    'parent_id': '1382-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'irbesartan',
#    'parent_id': '1383-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isavuconazonium',
#    'parent_id': '3612-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isocarboxazid',
#    'parent_id': '1389-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isoetharine',
#    'parent_id': '1390-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isoflurophate ophthalmic',
#    'parent_id': '1392-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isoniazid',
#    'parent_id': '1393-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isoproterenol',
#    'parent_id': '1397-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isosorbide',
#    'parent_id': '1399-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isosorbide dinitrate',
#    'parent_id': '1400-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isosorbide mononitrate',
#    'parent_id': '1401-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isoxsuprine',
#    'parent_id': '1404-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'isradipine',
#    'parent_id': '1405-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'itraconazole',
#    'parent_id': '1406-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ivacaftor',
#    'parent_id': '3371-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ivosidenib',
#    'parent_id': '3927-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'kava',
#    'parent_id': '2381-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'ketamine',
#    'parent_id': '1411-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ketoconazole',
#    'parent_id': '1412-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'labetalol',
#    'parent_id': '1420-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lamotrigine',
#    'parent_id': '1430-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lapatinib',
#    'parent_id': '1436-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'larotrectinib',
#    'parent_id': '3980-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lasmiditan',
#    'parent_id': '4095-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lefamulin',
#    'parent_id': '4085-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lenvatinib',
#    'parent_id': '3604-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lesinurad',
#    'parent_id': '3725-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'letermovir',
#    'parent_id': '3873-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'leuprolide',
#    'parent_id': '1445-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levalbuterol',
#    'parent_id': '1446-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levamlodipine',
#    'parent_id': '4120-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levetiracetam',
#    'parent_id': '1448-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levocetirizine',
#    'parent_id': '1455-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levodopa',
#    'parent_id': '1456-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levofloxacin',
#    'parent_id': '1457-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levoketoconazole',
#    'parent_id': '4330-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'levomethadyl acetate',
#    'parent_id': '1459-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'levomilnacipran',
#    'parent_id': '3483-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'levorphanol',
#    'parent_id': '1462-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'linagliptin',
#    'parent_id': '3322-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lindane topical',
#    'parent_id': '1471-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'liraglutide',
#    'parent_id': '3189-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lisdexamfetamine',
#    'parent_id': '1475-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lisinopril',
#    'parent_id': '1476-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lithium',
#    'parent_id': '1477-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lixisenatide',
#    'parent_id': '3760-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lofexidine',
#    'parent_id': '3910-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lomefloxacin',
#    'parent_id': '1480-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lomitapide',
#    'parent_id': '3437-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lonafarnib',
#    'parent_id': '4203-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lonapegsomatropin',
#    'parent_id': '4294-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'loperamide',
#    'parent_id': '1482-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lorazepam',
#    'parent_id': '1488-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lorcaserin',
#    'parent_id': '3401-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lorlatinib',
#    'parent_id': '3974-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'losartan',
#    'parent_id': '1489-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'loxapine',
#    'parent_id': '1494-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lumateperone',
#    'parent_id': '4114-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'lurasidone',
#    'parent_id': '3278-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'macimorelin',
#    'parent_id': '3886-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'maprotiline',
#    'parent_id': '1527-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mavacamten',
#    'parent_id': '4360-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mecamylamine',
#    'parent_id': '1536-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'meclizine',
#    'parent_id': '1540-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mefloquine',
#    'parent_id': '1546-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'melatonin',
#    'parent_id': '1548-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'memantine',
#    'parent_id': '1551-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mepenzolate',
#    'parent_id': '1556-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'meperidine',
#    'parent_id': '1557-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mephenytoin',
#    'parent_id': '1560-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mephobarbital',
#    'parent_id': '1561-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'meprobamate',
#    'parent_id': '1563-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mesoridazine',
#    'parent_id': '1568-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'metaproterenol',
#    'parent_id': '1570-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'metaxalone',
#    'parent_id': '1572-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'metformin',
#    'parent_id': '1573-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'methadone',
#    'parent_id': '1578-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methdilazine',
#    'parent_id': '1581-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methocarbamol',
#    'parent_id': '1588-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methohexital',
#    'parent_id': '1589-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methotrimeprazine',
#    'parent_id': '1591-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methscopolamine',
#    'parent_id': '1596-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methsuximide',
#    'parent_id': '1598-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methyclothiazide',
#    'parent_id': '1599-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'methyldopa',
#    'parent_id': '1603-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'metoclopramide',
#    'parent_id': '1612-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'metolazone',
#    'parent_id': '1614-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'metoprolol',
#    'parent_id': '1615-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'metrizamide',
#    'parent_id': '1616-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'metronidazole',
#    'parent_id': '1617-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'metyrosine',
#    'parent_id': '1620-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mibefradil',
#    'parent_id': '1623-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'miconazole',
#    'parent_id': '1625-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'midazolam',
#    'parent_id': '1628-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'midostaurin',
#    'parent_id': '3804-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mifepristone',
#    'parent_id': '1630-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'miglitol',
#    'parent_id': '1631-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'milnacipran',
#    'parent_id': '3101-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'minoxidil',
#    'parent_id': '1638-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mirabegron',
#    'parent_id': '3402-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mirtazapine',
#    'parent_id': '1640-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mitapivat',
#    'parent_id': '4342-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mitotane',
#    'parent_id': '1643-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'mobocertinib',
#    'parent_id': '4298-0',
#    'id': '233-109'},
#   {'class': 'Minor',
#    'name': 'modafinil',
#    'parent_id': '1647-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'moexipril',
#    'parent_id': '1648-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'molindone',
#    'parent_id': '1649-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'morphine',
#    'parent_id': '1656-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'morphine liposomal',
#    'parent_id': '1657-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'moxifloxacin',
#    'parent_id': '1659-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nabilone',
#    'parent_id': '1673-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nadolol',
#    'parent_id': '1675-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nafcillin',
#    'parent_id': '1677-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'nalbuphine',
#    'parent_id': '1679-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nateglinide',
#    'parent_id': '1695-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nebivolol',
#    'parent_id': '2788-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nefazodone',
#    'parent_id': '1698-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nelfinavir',
#    'parent_id': '1700-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nevirapine',
#    'parent_id': '1710-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nicardipine',
#    'parent_id': '1713-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nifedipine',
#    'parent_id': '1717-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nilotinib',
#    'parent_id': '2785-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nilutamide',
#    'parent_id': '1718-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nimodipine',
#    'parent_id': '1719-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nisoldipine',
#    'parent_id': '1720-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nitroglycerin',
#    'parent_id': '2342-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nitroprusside',
#    'parent_id': '1726-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'norfloxacin',
#    'parent_id': '1731-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'nortriptyline',
#    'parent_id': '1734-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ofloxacin',
#    'parent_id': '1741-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'olanzapine',
#    'parent_id': '1744-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'oliceridine',
#    'parent_id': '4180-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'olmesartan',
#    'parent_id': '1745-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'olodaterol',
#    'parent_id': '3547-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'olopatadine nasal',
#    'parent_id': '2830-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ondansetron',
#    'parent_id': '1752-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'opicapone',
#    'parent_id': '4148-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'opium',
#    'parent_id': '1754-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'orphenadrine',
#    'parent_id': '1757-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'osilodrostat',
#    'parent_id': '4141-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'osimertinib',
#    'parent_id': '3709-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'oxaliplatin',
#    'parent_id': '1760-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'oxamniquine',
#    'parent_id': '1761-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'oxazepam',
#    'parent_id': '1764-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'oxcarbazepine',
#    'parent_id': '1765-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'oxybutynin',
#    'parent_id': '1768-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'oxycodone',
#    'parent_id': '1770-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'oxymorphone',
#    'parent_id': '1773-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'oxytocin',
#    'parent_id': '1777-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'ozanimod',
#    'parent_id': '4142-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pacritinib',
#    'parent_id': '4344-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'palbociclib',
#    'parent_id': '3602-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'paliperidone',
#    'parent_id': '1781-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'palonosetron',
#    'parent_id': '1783-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'panobinostat',
#    'parent_id': '3605-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'papaverine',
#    'parent_id': '1792-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'paraldehyde',
#    'parent_id': '1794-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'paramethadione',
#    'parent_id': '1795-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'paroxetine',
#    'parent_id': '1800-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pasireotide',
#    'parent_id': '3435-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pazopanib',
#    'parent_id': '3180-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'penbutolol',
#    'parent_id': '1812-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pentamidine',
#    'parent_id': '1818-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'pentazocine',
#    'parent_id': '1820-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pentobarbital',
#    'parent_id': '1823-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'perampanel',
#    'parent_id': '3426-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'perflutren',
#    'parent_id': '1828-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pergolide',
#    'parent_id': '1829-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'perindopril',
#    'parent_id': '1830-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'perphenazine',
#    'parent_id': '1832-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
# ...
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pregabalin',
#    'parent_id': '1937-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'primaquine',
#    'parent_id': '1939-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'primidone',
#    'parent_id': '1940-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'probucol',
#    'parent_id': '1942-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'procainamide',
#    'parent_id': '1943-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'prochlorperazine',
#    'parent_id': '1946-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'procyclidine',
#    'parent_id': '1947-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'promazine',
#    'parent_id': '1948-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'promethazine',
#    'parent_id': '1949-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'propafenone',
#    'parent_id': '1950-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'propantheline',
#    'parent_id': '1951-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'propiomazine',
#    'parent_id': '1953-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'propofol',
#    'parent_id': '1954-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'propoxyphene',
#    'parent_id': '1955-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'propranolol',
#    'parent_id': '1956-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'protriptyline',
#    'parent_id': '1962-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'pyrilamine',
#    'parent_id': '1973-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'quazepam',
#    'parent_id': '1978-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'quetiapine',
#    'parent_id': '1979-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'quinapril',
#    'parent_id': '1980-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'quinidine',
#    'parent_id': '1981-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'quinine',
#    'parent_id': '1982-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ramelteon',
#    'parent_id': '1988-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ramipril',
#    'parent_id': '1989-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ranolazine',
#    'parent_id': '1993-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rasagiline',
#    'parent_id': '1995-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rauwolfia serpentina',
#    'parent_id': '1997-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'relugolix',
#    'parent_id': '4227-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'remifentanil',
#    'parent_id': '1999-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'remimazolam',
#    'parent_id': '4165-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'repaglinide',
#    'parent_id': '2000-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'reserpine',
#    'parent_id': '2001-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'revefenacin',
#    'parent_id': '3975-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ribociclib',
#    'parent_id': '3790-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rifabutin',
#    'parent_id': '2011-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rifampin',
#    'parent_id': '2012-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rifapentine',
#    'parent_id': '2013-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rilpivirine',
#    'parent_id': '3327-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'risperidone',
#    'parent_id': '2019-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ritodrine',
#    'parent_id': '2020-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ritonavir',
#    'parent_id': '2021-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rivastigmine',
#    'parent_id': '2023-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rolapitant',
#    'parent_id': '3678-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'romidepsin',
#    'parent_id': '3183-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ropinirole',
#    'parent_id': '2027-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rosiglitazone',
#    'parent_id': '2030-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rotigotine',
#    'parent_id': '2033-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'rucaparib',
#    'parent_id': '3778-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'safinamide',
#    'parent_id': '3793-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'salmeterol',
#    'parent_id': '2041-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'saquinavir',
#    'parent_id': '2044-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'saxagliptin',
#    'parent_id': '3160-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'scopolamine',
#    'parent_id': '2047-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'secobarbital',
#    'parent_id': '2049-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'selegiline',
#    'parent_id': '2051-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'selpercatinib',
#    'parent_id': '4151-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'semaglutide',
#    'parent_id': '3878-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sertraline',
#    'parent_id': '2057-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sevoflurane',
#    'parent_id': '2059-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sibutramine',
#    'parent_id': '2060-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'silodosin',
#    'parent_id': '2960-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'siponimod',
#    'parent_id': '4001-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sirolimus',
#    'parent_id': '2069-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sitagliptin',
#    'parent_id': '2070-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'sodium oxybate',
#    'parent_id': '2091-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'solifenacin',
#    'parent_id': '2098-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'somapacitan-beco',
#    'parent_id': '4188-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'somatrem',
#    'parent_id': '2099-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'somatropin',
#    'parent_id': '2100-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sorafenib',
#    'parent_id': '2101-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sotalol',
#    'parent_id': '2102-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sotorasib',
#    'parent_id': '4266-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sparfloxacin',
#    'parent_id': '2103-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'spironolactone',
#    'parent_id': '2105-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': "st. john's wort",
#    'parent_id': '2106-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'stiripentol',
#    'parent_id': '3952-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'sufentanil',
#    'parent_id': '2119-0',
#    'id': '233-109'},
#   {'class': 'Minor',
#    'name': 'sulfamethoxazole',
#    'parent_id': '2127-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sulfinpyrazone',
#    'parent_id': '2131-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'sunitinib',
#    'parent_id': '2138-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'suvorexant',
#    'parent_id': '3554-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tacrine',
#    'parent_id': '2141-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tacrolimus',
#    'parent_id': '2142-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tamoxifen',
#    'parent_id': '2145-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tamsulosin',
#    'parent_id': '2146-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'tapentadol',
#    'parent_id': '3132-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tasimelteon',
#    'parent_id': '3507-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tazemetostat',
#    'parent_id': '4127-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'telaprevir',
#    'parent_id': '3328-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'telavancin',
#    'parent_id': '3173-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'telithromycin',
#    'parent_id': '2151-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'telmisartan',
#    'parent_id': '2152-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'telotristat',
#    'parent_id': '3787-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'temazepam',
#    'parent_id': '2153-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'temsirolimus',
#    'parent_id': '2155-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'terazosin',
#    'parent_id': '2159-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'terbinafine',
#    'parent_id': '2161-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'terbutaline',
#    'parent_id': '2162-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'terfenadine',
#    'parent_id': '2164-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'tetrabenazine',
#    'parent_id': '2918-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'thalidomide',
#    'parent_id': '2176-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'thiethylperazine',
#    'parent_id': '2180-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'thiopental',
#    'parent_id': '2183-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'thioridazine',
#    'parent_id': '2184-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'thiothixene',
#    'parent_id': '2186-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tiagabine',
#    'parent_id': '2191-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ticagrelor',
#    'parent_id': '3336-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ticlopidine',
#    'parent_id': '2193-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'timolol',
#    'parent_id': '2196-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tiotropium',
#    'parent_id': '2202-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tirzepatide',
#    'parent_id': '4363-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tizanidine',
#    'parent_id': '2205-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tolazamide',
#    'parent_id': '2209-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tolazoline',
#    'parent_id': '2210-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tolbutamide',
#    'parent_id': '2211-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tolcapone',
#    'parent_id': '2212-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tolterodine',
#    'parent_id': '2215-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'topiramate',
#    'parent_id': '2216-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'toremifene',
#    'parent_id': '2218-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'torsemide',
#    'parent_id': '2219-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'tramadol',
#    'parent_id': '2221-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trandolapril',
#    'parent_id': '2222-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tranylcypromine',
#    'parent_id': '2225-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trazodone',
#    'parent_id': '2228-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'triamterene',
#    'parent_id': '2234-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'triazolam',
#    'parent_id': '2235-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trichlormethiazide',
#    'parent_id': '2236-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'triclabendazole',
#    'parent_id': '3995-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trifluoperazine',
#    'parent_id': '2242-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'triflupromazine',
#    'parent_id': '2243-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trihexyphenidyl',
#    'parent_id': '2245-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trimeprazine',
#    'parent_id': '2246-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trimethadione',
#    'parent_id': '2247-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trimethaphan camsylate',
#    'parent_id': '2248-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trimethobenzamide',
#    'parent_id': '2249-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trimipramine',
#    'parent_id': '2252-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tripelennamine',
#    'parent_id': '2254-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'triprolidine',
#    'parent_id': '2257-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'triptorelin',
#    'parent_id': '2258-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'troglitazone',
#    'parent_id': '2259-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'troleandomycin',
#    'parent_id': '2261-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'trospium',
#    'parent_id': '2264-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'tucatinib',
#    'parent_id': '4144-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'umeclidinium',
#    'parent_id': '3528-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'valbenazine',
#    'parent_id': '3800-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'valerian',
#    'parent_id': '2284-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'valproic acid',
#    'parent_id': '2286-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'valsartan',
#    'parent_id': '2288-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'vandetanib',
#    'parent_id': '3312-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'vardenafil',
#    'parent_id': '2290-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'vasopressin',
#    'parent_id': '2294-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'vemurafenib',
#    'parent_id': '3338-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'venlafaxine',
#    'parent_id': '2296-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'verapamil',
#    'parent_id': '2297-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'vigabatrin',
#    'parent_id': '3169-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'viloxazine',
#    'parent_id': '4254-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'voclosporin',
#    'parent_id': '4234-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'voriconazole',
#    'parent_id': '2309-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'voxelotor',
#    'parent_id': '4107-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'zafirlukast',
#    'parent_id': '2317-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'zaleplon',
#    'parent_id': '2319-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ziconotide',
#    'parent_id': '2321-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'ziprasidone',
#    'parent_id': '2330-0',
#    'id': '233-109'},
#   {'class': 'Moderate',
#    'name': 'zolpidem',
#    'parent_id': '2333-0',
#    'id': '233-109'},
#   {'class': 'Major',
#    'name': 'zonisamide',
#    'parent_id': '2334-0',
#    'id': '233-109'}]}

# %%
drugs_interactions_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 drugs_interactions_list
#
# NameError: name 'drugs_interactions_list' is not defined

# %%
with open('data/drug_interactions.json','w') as fp:
    json.dump(drug_interactions_list_with_key,fp)

# %%
drug_interactions_list_with_key[0]
# Out:
# {'drug name': 'Abilify',
#  'drug_interactions': [{'class': 'Moderate',
#    'name': 'abametapir topical',
#    'id': '233-109'},
#   {'class': 'Moderate', 'name': 'abarelix', 'id': '233-109'},
#   {'class': 'Moderate', 'name': 'abiraterone', 'id': '3321-0'},
#   {'class': 'Moderate', 'name': 'acarbose', 'id': '9-0'},
#   {'class': 'Moderate', 'name': 'acebutolol', 'id': '10-0'},
#   {'class': 'Moderate', 'name': 'acetohexamide', 'id': '93-0'},
#   {'class': 'Moderate', 'name': 'acetylcarbromal', 'id': '95-0'},
#   {'class': 'Moderate', 'name': 'acetylcholine ophthalmic', 'id': '96-0'},
#   {'class': 'Moderate', 'name': 'aclidinium', 'id': '3406-0'},
#   {'class': 'Moderate', 'name': 'acrivastine', 'id': '2875-0'},
#   {'class': 'Moderate', 'name': 'albiglutide', 'id': '3524-0'},
#   {'class': 'Moderate', 'name': 'albuterol', 'id': '109-0'},
#   {'class': 'Major', 'name': 'alfentanil', 'id': '118-0'},
#   {'class': 'Moderate', 'name': 'alfuzosin', 'id': '119-0'},
#   {'class': 'Moderate', 'name': 'alogliptin', 'id': '3448-0'},
#   {'class': 'Moderate', 'name': 'alprazolam', 'id': '133-0'},
#   {'class': 'Moderate', 'name': 'amantadine', 'id': '148-0'},
#   {'class': 'Moderate', 'name': 'amifampridine', 'id': '3982-0'},
#   {'class': 'Moderate', 'name': 'amiloride', 'id': '154-0'},
#   {'class': 'Moderate', 'name': 'aminoglutethimide', 'id': '158-0'},
#   {'class': 'Moderate', 'name': 'amiodarone', 'id': '167-0'},
#   {'class': 'Moderate', 'name': 'amisulpride', 'id': '4134-0'},
#   {'class': 'Moderate', 'name': 'amitriptyline', 'id': '168-0'},
#   {'class': 'Moderate', 'name': 'amlodipine', 'id': '172-0'},
#   {'class': 'Moderate', 'name': 'amobarbital', 'id': '184-0'},
#   {'class': 'Moderate', 'name': 'amoxapine', 'id': '186-0'},
#   {'class': 'Moderate', 'name': 'amprenavir', 'id': '199-0'},
#   {'class': 'Moderate', 'name': 'amyl nitrite', 'id': '200-0'},
#   {'class': 'Moderate', 'name': 'anagrelide', 'id': '204-0'},
#   {'class': 'Moderate', 'name': 'apalutamide', 'id': '3893-0'},
#   {'class': 'Moderate', 'name': 'apomorphine', 'id': '224-0'},
#   {'class': 'Moderate', 'name': 'apraclonidine ophthalmic', 'id': '225-0'},
#   {'class': 'Moderate', 'name': 'aprepitant', 'id': '226-0'},
#   {'class': 'Moderate', 'name': 'arformoterol', 'id': '230-0'},
#   {'class': 'Minor', 'name': 'armodafinil', 'id': '234-0'},
#   {'class': 'Moderate', 'name': 'arsenic trioxide', 'id': '236-0'},
#   {'class': 'Moderate', 'name': 'asciminib', 'id': '4307-0'},
#   {'class': 'Moderate', 'name': 'asenapine', 'id': '3168-0'},
#   {'class': 'Moderate', 'name': 'astemizole', 'id': '271-0'},
#   {'class': 'Moderate', 'name': 'atazanavir', 'id': '272-0'},
#   {'class': 'Moderate', 'name': 'atenolol', 'id': '273-0'},
#   {'class': 'Moderate', 'name': 'atomoxetine', 'id': '275-0'},
#   {'class': 'Moderate', 'name': 'atropine', 'id': '280-0'},
#   {'class': 'Moderate', 'name': 'avacopan', 'id': '4305-0'},
#   {'class': 'Moderate', 'name': 'azatadine', 'id': '294-0'},
#   {'class': 'Moderate', 'name': 'azelastine nasal', 'id': '298-0'},
#   {'class': 'Moderate', 'name': 'azilsartan medoxomil', 'id': '3302-0'},
#   {'class': 'Moderate', 'name': 'azithromycin', 'id': '300-0'},
#   {'class': 'Moderate', 'name': 'baclofen', 'id': '318-0'},
#   {'class': 'Moderate', 'name': 'bedaquiline', 'id': '3439-0'},
#   {'class': 'Moderate', 'name': 'belladonna', 'id': '327-0'},
#   {'class': 'Moderate', 'name': 'belzutifan', 'id': '4289-0'},
#   {'class': 'Moderate', 'name': 'benazepril', 'id': '332-0'},
#   {'class': 'Moderate', 'name': 'bendroflumethiazide', 'id': '334-0'},
#   {'class': 'Moderate', 'name': 'benzthiazide', 'id': '362-0'},
#   {'class': 'Moderate', 'name': 'benztropine', 'id': '363-0'},
#   {'class': 'Moderate', 'name': 'bepridil', 'id': '366-0'},
#   {'class': 'Moderate', 'name': 'berotralstat', 'id': '4224-0'},
#   {'class': 'Moderate', 'name': 'betaxolol', 'id': '374-0'},
#   {'class': 'Moderate', 'name': 'bexarotene', 'id': '378-0'},
#   {'class': 'Moderate', 'name': 'bicalutamide', 'id': '380-0'},
#   {'class': 'Moderate', 'name': 'biperiden', 'id': '384-0'},
#   {'class': 'Moderate', 'name': 'bisoprolol', 'id': '393-0'},
#   {'class': 'Moderate', 'name': 'bitolterol', 'id': '395-0'},
#   {'class': 'Moderate', 'name': 'boceprevir', 'id': '3323-0'},
#   {'class': 'Moderate', 'name': 'bosentan', 'id': '403-0'},
#   {'class': 'Moderate', 'name': 'bosutinib', 'id': '3416-0'},
#   {'class': 'Moderate', 'name': 'brexanolone', 'id': '3999-0'},
#   {'class': 'Moderate', 'name': 'brexpiprazole', 'id': '3639-0'},
#   {'class': 'Moderate', 'name': 'brimonidine ophthalmic', 'id': '410-0'},
#   {'class': 'Moderate', 'name': 'brimonidine topical', 'id': '3487-0'},
#   {'class': 'Moderate', 'name': 'brivaracetam', 'id': '3728-0'},
#   {'class': 'Moderate', 'name': 'bromocriptine', 'id': '414-0'},
#   {'class': 'Moderate', 'name': 'brompheniramine', 'id': '416-0'},
#   {'class': 'Moderate', 'name': 'bumetanide', 'id': '433-0'},
#   {'class': 'Major', 'name': 'buprenorphine', 'id': '438-0'},
#   {'class': 'Major', 'name': 'bupropion', 'id': '440-0'},
#   {'class': 'Moderate', 'name': 'buspirone', 'id': '441-0'},
#   {'class': 'Moderate', 'name': 'butabarbital', 'id': '443-0'},
#   {'class': 'Moderate', 'name': 'butalbital', 'id': '2338-0'},
#   {'class': 'Major', 'name': 'butorphanol', 'id': '448-0'},
#   {'class': 'Moderate', 'name': 'cabergoline', 'id': '449-0'},
#   {'class': 'Moderate', 'name': 'cabozantinib', 'id': '3430-0'},
#   {'class': 'Moderate', 'name': 'canagliflozin', 'id': '3465-0'},
#   {'class': 'Moderate', 'name': 'candesartan', 'id': '487-0'},
#   {'class': 'Moderate', 'name': 'cannabidiol', 'id': '3919-0'},
#   {'class': 'Moderate', 'name': 'cannabis', 'id': '2758-0'},
#   {'class': 'Moderate', 'name': 'captopril', 'id': '493-0'},
#   {'class': 'Moderate', 'name': 'carbachol ophthalmic', 'id': '496-0'},
#   {'class': 'Moderate', 'name': 'carbamazepine', 'id': '497-0'},
#   {'class': 'Moderate', 'name': 'carbetapentane', 'id': '2804-0'},
#   {'class': 'Moderate', 'name': 'carbinoxamine', 'id': '516-0'},
#   {'class': 'Moderate', 'name': 'cariprazine', 'id': '3684-0'},
#   {'class': 'Moderate', 'name': 'carisoprodol', 'id': '527-0'},
#   {'class': 'Moderate', 'name': 'carteolol', 'id': '529-0'},
#   {'class': 'Moderate', 'name': 'carvedilol', 'id': '531-0'},
#   {'class': 'Moderate', 'name': 'celecoxib', 'id': '560-0'},
#   {'class': 'Moderate', 'name': 'cenobamate', 'id': '4105-0'},
#   {'class': 'Moderate', 'name': 'ceritinib', 'id': '3527-0'},
#   {'class': 'Moderate', 'name': 'cetirizine', 'id': '569-0'},
#   {'class': 'Moderate', 'name': 'chlophedianol', 'id': '3182-0'},
#   {'class': 'Moderate', 'name': 'chloral hydrate', 'id': '577-0'},
#   {'class': 'Moderate', 'name': 'chloramphenicol', 'id': '579-0'},
#   {'class': 'Moderate', 'name': 'chlorcyclizine', 'id': '3268-0'},
#   {'class': 'Moderate', 'name': 'chlordiazepoxide', 'id': '585-0'},
#   {'class': 'Moderate', 'name': 'chlormezanone', 'id': '589-0'},
#   {'class': 'Moderate', 'name': 'chloroquine', 'id': '593-0'},
#   {'class': 'Moderate', 'name': 'chlorothiazide', 'id': '594-0'},
#   {'class': 'Moderate', 'name': 'chlorphenesin', 'id': '603-0'},
#   {'class': 'Moderate', 'name': 'chlorpheniramine', 'id': '604-0'},
#   {'class': 'Moderate', 'name': 'chlorpromazine', 'id': '639-0'},
#   {'class': 'Moderate', 'name': 'chlorpropamide', 'id': '640-0'},
#   {'class': 'Moderate', 'name': 'chlorthalidone', 'id': '642-0'},
#   {'class': 'Moderate', 'name': 'chlorzoxazone', 'id': '645-0'},
#   {'class': 'Moderate', 'name': 'cilostazol', 'id': '668-0'},
#   {'class': 'Moderate', 'name': 'cimetidine', 'id': '669-0'},
#   {'class': 'Moderate', 'name': 'cinacalcet', 'id': '670-0'},
#   {'class': 'Moderate', 'name': 'ciprofloxacin', 'id': '672-0'},
#   {'class': 'Moderate', 'name': 'cisapride', 'id': '676-0'},
#   {'class': 'Moderate', 'name': 'citalopram', 'id': '679-0'},
#   {'class': 'Moderate', 'name': 'clarithromycin', 'id': '685-0'},
#   {'class': 'Moderate', 'name': 'clemastine', 'id': '687-0'},
#   {'class': 'Moderate', 'name': 'clevidipine', 'id': '2909-0'},
#   {'class': 'Moderate', 'name': 'clidinium', 'id': '689-0'},
#   {'class': 'Moderate', 'name': 'clobazam', 'id': '3350-0'},
#   {'class': 'Moderate', 'name': 'clofazimine', 'id': '699-0'},
#   {'class': 'Moderate', 'name': 'clomipramine', 'id': '702-0'},
#   {'class': 'Moderate', 'name': 'clonazepam', 'id': '703-0'},
#   {'class': 'Moderate', 'name': 'clonidine', 'id': '704-0'},
#   {'class': 'Moderate', 'name': 'clorazepate', 'id': '706-0'},
#   {'class': 'Moderate', 'name': 'clotrimazole', 'id': '3106-0'},
#   {'class': 'Major', 'name': 'clozapine', 'id': '709-0'},
#   {'class': 'Moderate', 'name': 'cobicistat', 'id': '3565-0'},
#   {'class': 'Major', 'name': 'codeine', 'id': '718-0'},
#   {'class': 'Moderate', 'name': 'conivaptan', 'id': '737-0'},
#   {'class': 'Moderate', 'name': 'crizotinib', 'id': '3342-0'},
#   {'class': 'Moderate', 'name': 'cyclandelate', 'id': '756-0'},
#   {'class': 'Moderate', 'name': 'cyclizine', 'id': '757-0'},
#   {'class': 'Moderate', 'name': 'cyclobenzaprine', 'id': '758-0'},
#   {'class': 'Moderate', 'name': 'cyclosporine', 'id': '763-0'},
#   {'class': 'Moderate', 'name': 'cyproheptadine', 'id': '765-0'},
#   {'class': 'Moderate', 'name': 'dabrafenib', 'id': '3475-0'},
#   {'class': 'Moderate', 'name': 'dacomitinib', 'id': '3962-0'},
#   {'class': 'Moderate', 'name': 'danazol', 'id': '778-0'},
#   {'class': 'Moderate', 'name': 'dantrolene', 'id': '779-0'},
#   {'class': 'Moderate', 'name': 'dapagliflozin', 'id': '3506-0'},
#   {'class': 'Moderate', 'name': 'daridorexant', 'id': '4332-0'},
#   {'class': 'Moderate', 'name': 'darifenacin', 'id': '785-0'},
#   {'class': 'Moderate', 'name': 'darunavir', 'id': '786-0'},
#   {'class': 'Moderate', 'name': 'dasatinib', 'id': '787-0'},
#   {'class': 'Moderate', 'name': 'daunorubicin', 'id': '788-0'},
#   {'class': 'Moderate', 'name': 'daunorubicin liposomal', 'id': '789-0'},
#   {'class': 'Moderate', 'name': 'deferasirox', 'id': '791-0'},
#   {'class': 'Moderate', 'name': 'degarelix', 'id': '3102-0'},
#   {'class': 'Moderate', 'name': 'delavirdine', 'id': '794-0'},
#   {'class': 'Moderate',
#    'name': 'demecarium bromide ophthalmic',
#    'id': '795-0'},
#   {'class': 'Moderate', 'name': 'deserpidine', 'id': '798-0'},
#   {'class': 'Moderate', 'name': 'desipramine', 'id': '802-0'},
#   {'class': 'Moderate', 'name': 'desvenlafaxine', 'id': '2796-0'},
#   {'class': 'Major', 'name': 'deutetrabenazine', 'id': '3799-0'},
#   {'class': 'Moderate', 'name': 'dexamethasone', 'id': '810-0'},
#   {'class': 'Moderate', 'name': 'dexbrompheniramine', 'id': '3387-0'},
#   {'class': 'Moderate', 'name': 'dexchlorpheniramine', 'id': '824-0'},
#   {'class': 'Moderate', 'name': 'dexfenfluramine', 'id': '834-0'},
#   {'class': 'Moderate', 'name': 'dexmedetomidine', 'id': '835-0'},
#   {'class': 'Moderate', 'name': 'dextromethorphan', 'id': '844-0'},
#   {'class': 'Major', 'name': 'dezocine', 'id': '859-0'},
#   {'class': 'Moderate', 'name': 'diazepam', 'id': '862-0'},
#   {'class': 'Moderate', 'name': 'diazoxide', 'id': '863-0'},
#   {'class': 'Moderate', 'name': 'dicyclomine', 'id': '875-0'},
#   {'class': 'Moderate', 'name': 'difelikefalin', 'id': '4293-0'},
#   {'class': 'Moderate', 'name': 'diltiazem', 'id': '890-0'},
#   {'class': 'Moderate', 'name': 'dimenhydrinate', 'id': '892-0'},
#   {'class': 'Moderate', 'name': 'diphenhydramine', 'id': '896-0'},
#   {'class': 'Moderate', 'name': 'disopyramide', 'id': '916-0'},
#   {'class': 'Moderate', 'name': 'divalproex sodium', 'id': '918-0'},
#   {'class': 'Moderate', 'name': 'dofetilide', 'id': '925-0'},
#   {'class': 'Moderate', 'name': 'dolasetron', 'id': '926-0'},
#   {'class': 'Moderate', 'name': 'donepezil', 'id': '927-0'},
#   {'class': 'Moderate', 'name': 'dopamine', 'id': '928-0'},
#   {'class': 'Moderate', 'name': 'doxazosin', 'id': '934-0'},
#   {'class': 'Moderate', 'name': 'doxepin', 'id': '935-0'},
#   {'class': 'Moderate', 'name': 'doxepin topical', 'id': '936-0'},
#   {'class': 'Moderate', 'name': 'doxorubicin', 'id': '938-0'},
#   {'class': 'Moderate', 'name': 'doxorubicin liposomal', 'id': '939-0'},
#   {'class': 'Moderate', 'name': 'doxylamine', 'id': '942-0'},
#   {'class': 'Moderate', 'name': 'dronabinol', 'id': '943-0'},
#   {'class': 'Moderate', 'name': 'dronedarone', 'id': '3147-0'},
#   {'class': 'Moderate', 'name': 'droperidol', 'id': '944-0'},
#   {'class': 'Moderate', 'name': 'dulaglutide', 'id': '3562-0'},
#   {'class': 'Moderate', 'name': 'duloxetine', 'id': '949-0'},
#   {'class': 'Moderate', 'name': 'duvelisib', 'id': '3961-0'},
#   {'class': 'Moderate', 'name': 'echinacea', 'id': '955-0'},
#   {'class': 'Moderate',
#    'name': 'echothiophate iodide ophthalmic',
#    'id': '956-0'},
#   {'class': 'Moderate', 'name': 'efavirenz', 'id': '963-0'},
#   {'class': 'Moderate', 'name': 'elagolix', 'id': '3930-0'},
#   {'class': 'Moderate', 'name': 'eliglustat', 'id': '3556-0'},
#   {'class': 'Moderate', 'name': 'eluxadoline', 'id': '3630-0'},
#   {'class': 'Moderate', 'name': 'empagliflozin', 'id': '3548-0'},
#   {'class': 'Moderate', 'name': 'enalapril', 'id': '972-0'},
#   {'class': 'Moderate', 'name': 'enalaprilat', 'id': '2367-0'},
#   {'class': 'Moderate', 'name': 'encorafenib', 'id': '3921-0'},
#   {'class': 'Moderate', 'name': 'entacapone', 'id': '979-0'},
#   {'class': 'Moderate', 'name': 'entrectinib', 'id': '4082-0'},
#   {'class': 'Moderate', 'name': 'enzalutamide', 'id': '3414-0'},
#   {'class': 'Moderate', 'name': 'epinephrine', 'id': '989-0'},
#   {'class': 'Moderate', 'name': 'epirubicin', 'id': '996-0'},
#   {'class': 'Moderate', 'name': 'eplerenone', 'id': '997-0'},
#   {'class': 'Moderate', 'name': 'eprosartan', 'id': '1000-0'},
#   {'class': 'Moderate', 'name': 'eribulin', 'id': '3284-0'},
#   {'class': 'Moderate', 'name': 'ertugliflozin', 'id': '3883-0'},
#   {'class': 'Moderate', 'name': 'erythromycin', 'id': '1009-0'},
#   {'class': 'Moderate', 'name': 'escitalopram', 'id': '1013-0'},
#   {'class': 'Moderate', 'name': 'esketamine', 'id': '3996-0'},
#   {'class': 'Moderate', 'name': 'eslicarbazepine', 'id': '3499-0'},
#   {'class': 'Moderate', 'name': 'esmolol', 'id': '1014-0'},
#   {'class': 'Moderate', 'name': 'estazolam', 'id': '1016-0'},
#   {'class': 'Moderate', 'name': 'eszopiclone', 'id': '1030-0'},
#   {'class': 'Moderate', 'name': 'ethacrynic acid', 'id': '1032-0'},
#   {'class': 'Moderate', 'name': 'ethanol', 'id': '1034-0'},
#   {'class': 'Moderate', 'name': 'ethaverine', 'id': '1037-0'},
#   {'class': 'Moderate', 'name': 'ethchlorvynol', 'id': '1038-0'},
#   {'class': 'Moderate', 'name': 'ethosuximide', 'id': '1049-0'},
#   {'class': 'Moderate', 'name': 'ethotoin', 'id': '1050-0'},
#   {'class': 'Moderate', 'name': 'etravirine', 'id': '2793-0'},
#   {'class': 'Minor', 'name': 'evening primrose', 'id': '1059-0'},
#   {'class': 'Moderate', 'name': 'exenatide', 'id': '1061-0'},
#   {'class': 'Moderate', 'name': 'ezogabine', 'id': '3330-0'},
#   {'class': 'Moderate', 'name': 'famotidine', 'id': '1066-0'},
#   {'class': 'Moderate', 'name': 'fedratinib', 'id': '4083-0'},
#   {'class': 'Moderate', 'name': 'felbamate', 'id': '1068-0'},
#   {'class': 'Moderate', 'name': 'felodipine', 'id': '1069-0'},
#   {'class': 'Moderate', 'name': 'fenfluramine', 'id': '1070-0'},
#   {'class': 'Moderate', 'name': 'fenoldopam', 'id': '1072-0'},
#   {'class': 'Major', 'name': 'fentanyl', 'id': '1074-0'},
#   {'class': 'Moderate', 'name': 'fesoterodine', 'id': '2962-0'},
#   {'class': 'Moderate', 'name': 'fexinidazole', 'id': '4280-0'},
#   {'class': 'Moderate', 'name': 'fingolimod', 'id': '3264-0'},
#   {'class': 'Moderate', 'name': 'flavoxate', 'id': '1092-0'},
#   {'class': 'Moderate', 'name': 'flecainide', 'id': '1094-0'},
#   {'class': 'Moderate', 'name': 'flibanserin', 'id': '3675-0'},
#   {'class': 'Moderate', 'name': 'fluconazole', 'id': '1096-0'},
#   {'class': 'Moderate', 'name': 'fluoxetine', 'id': '1115-0'},
#   {'class': 'Moderate', 'name': 'fluphenazine', 'id': '1118-0'},
#   {'class': 'Moderate', 'name': 'flurazepam', 'id': '1120-0'},
#   {'class': 'Moderate', 'name': 'flutamide', 'id': '1123-0'},
#   {'class': 'Moderate', 'name': 'fluvoxamine', 'id': '1128-0'},
#   {'class': 'Moderate', 'name': 'formoterol', 'id': '1136-0'},
#   {'class': 'Moderate', 'name': 'fosamprenavir', 'id': '1137-0'},
#   {'class': 'Moderate', 'name': 'fosaprepitant', 'id': '2862-0'},
#   {'class': 'Moderate', 'name': 'foscarnet', 'id': '1138-0'},
#   {'class': 'Moderate', 'name': 'fosinopril', 'id': '1140-0'},
#   {'class': 'Moderate', 'name': 'fosphenytoin', 'id': '1142-0'},
#   {'class': 'Moderate', 'name': 'fostamatinib', 'id': '3908-0'},
#   {'class': 'Moderate', 'name': 'fostemsavir', 'id': '4166-0'},
#   {'class': 'Moderate', 'name': 'furosemide', 'id': '1146-0'},
#   {'class': 'Moderate', 'name': 'gabapentin', 'id': '1147-0'},
#   {'class': 'Moderate', 'name': 'gabapentin enacarbil', 'id': '3488-0'},
#   {'class': 'Moderate', 'name': 'galantamine', 'id': '1153-0'},
#   {'class': 'Moderate', 'name': 'ganaxolone', 'id': '4348-0'},
#   {'class': 'Moderate', 'name': 'gatifloxacin', 'id': '1161-0'},
#   {'class': 'Moderate', 'name': 'gefitinib', 'id': '1163-0'},
#   {'class': 'Moderate', 'name': 'gemifloxacin', 'id': '1166-0'},
#   {'class': 'Moderate', 'name': 'gilteritinib', 'id': '3981-0'},
#   {'class': 'Moderate', 'name': 'ginkgo', 'id': '1174-0'},
#   {'class': 'Moderate', 'name': 'givosiran', 'id': '4104-0'},
#   {'class': 'Moderate', 'name': 'glasdegib', 'id': '3979-0'},
#   {'class': 'Moderate', 'name': 'glimepiride', 'id': '1176-0'},
#   {'class': 'Moderate', 'name': 'glipizide', 'id': '1179-0'},
#   {'class': 'Moderate', 'name': 'glyburide', 'id': '1185-0'},
#   {'class': 'Moderate', 'name': 'glycerol phenylbutyrate', 'id': '3452-0'},
#   {'class': 'Moderate', 'name': 'glycopyrrolate', 'id': '1192-0'},
#   {'class': 'Moderate', 'name': 'glycopyrronium topical', 'id': '3923-0'},
#   {'class': 'Moderate', 'name': 'goldenseal', 'id': '2508-0'},
#   {'class': 'Moderate', 'name': 'goserelin', 'id': '1195-0'},
#   {'class': 'Moderate', 'name': 'granisetron', 'id': '1197-0'},
#   {'class': 'Moderate', 'name': 'grepafloxacin', 'id': '1198-0'},
#   {'class': 'Moderate', 'name': 'griseofulvin', 'id': '1199-0'},
#   {'class': 'Moderate', 'name': 'guanabenz', 'id': '1215-0'},
#   {'class': 'Moderate', 'name': 'guanadrel', 'id': '1216-0'},
#   {'class': 'Moderate', 'name': 'guanethidine', 'id': '1217-0'},
#   {'class': 'Moderate', 'name': 'guanfacine', 'id': '1219-0'},
#   {'class': 'Moderate', 'name': 'halazepam', 'id': '1226-0'},
#   {'class': 'Moderate', 'name': 'halofantrine', 'id': '1229-0'},
#   {'class': 'Moderate', 'name': 'haloperidol', 'id': '1230-0'},
#   {'class': 'Moderate', 'name': 'halothane', 'id': '1232-0'},
#   {'class': 'Moderate', 'name': 'heroin', 'id': '2759-0'},
#   {'class': 'Moderate', 'name': 'histrelin', 'id': '1246-0'},
#   {'class': 'Moderate', 'name': 'hydralazine', 'id': '1253-0'},
#   {'class': 'Moderate', 'name': 'hydrochlorothiazide', 'id': '1257-0'},
#   {'class': 'Major', 'name': 'hydrocodone', 'id': '2874-0'},
#   {'class': 'Moderate', 'name': 'hydroflumethiazide', 'id': '1291-0'},
#   {'class': 'Major', 'name': 'hydromorphone', 'id': '1294-0'},
#   {'class': 'Moderate', 'name': 'hydroxychloroquine', 'id': '1298-0'},
#   {'class': 'Moderate', 'name': 'hydroxyzine', 'id': '1303-0'},
#   {'class': 'Moderate', 'name': 'hyoscyamine', 'id': '2513-0'},
#   {'class': 'Moderate', 'name': 'ibutilide', 'id': '1313-0'},
#   {'class': 'Moderate', 'name': 'idarubicin', 'id': '1315-0'},
#   {'class': 'Moderate', 'name': 'idelalisib', 'id': '3546-0'},
#   {'class': 'Moderate', 'name': 'ifosfamide', 'id': '1318-0'},
#   {'class': 'Moderate', 'name': 'iloperidone', 'id': '3140-0'},
#   {'class': 'Moderate', 'name': 'imatinib', 'id': '1321-0'},
#   {'class': 'Moderate', 'name': 'imipramine', 'id': '1323-0'},
#   {'class': 'Moderate', 'name': 'indacaterol', 'id': '3333-0'},
#   {'class': 'Moderate', 'name': 'indapamide', 'id': '1327-0'},
#   {'class': 'Moderate', 'name': 'indinavir', 'id': '1329-0'},
#   {'class': 'Moderate', 'name': 'inotuzumab ozogamicin', 'id': '3857-0'},
#   {'class': 'Moderate', 'name': 'insulin', 'id': '1340-0'},
#   {'class': 'Moderate', 'name': 'insulin aspart', 'id': '1341-0'},
#   {'class': 'Moderate', 'name': 'insulin aspart protamine', 'id': '2341-0'},
#   {'class': 'Moderate', 'name': 'insulin degludec', 'id': '3693-0'},
#   {'class': 'Moderate', 'name': 'insulin detemir', 'id': '1343-0'},
#   {'class': 'Moderate', 'name': 'insulin glargine', 'id': '1344-0'},
#   {'class': 'Moderate', 'name': 'insulin glulisine', 'id': '1345-0'},
#   {'class': 'Moderate',
#    'name': 'insulin inhalation, rapid acting',
#    'id': '1346-0'},
#   {'class': 'Moderate', 'name': 'insulin isophane', 'id': '1347-0'},
#   {'class': 'Moderate', 'name': 'insulin lispro', 'id': '1349-0'},
#   {'class': 'Moderate', 'name': 'insulin lispro protamine', 'id': '2766-0'},
#   {'class': 'Moderate', 'name': 'insulin regular', 'id': '1351-0'},
#   {'class': 'Moderate', 'name': 'insulin zinc', 'id': '1352-0'},
#   {'class': 'Moderate', 'name': 'insulin zinc extended', 'id': '1353-0'},
#   {'class': 'Moderate', 'name': 'ioflupane I 123', 'id': '3297-0'},
#   {'class': 'Major', 'name': 'iohexol', 'id': '1372-0'},
#   {'class': 'Major', 'name': 'iopamidol', 'id': '1373-0'},
#   {'class': 'Moderate', 'name': 'ipratropium', 'id': '1382-0'},
#   {'class': 'Moderate', 'name': 'irbesartan', 'id': '1383-0'},
#   {'class': 'Moderate', 'name': 'isavuconazonium', 'id': '3612-0'},
#   {'class': 'Moderate', 'name': 'isocarboxazid', 'id': '1389-0'},
#   {'class': 'Moderate', 'name': 'isoetharine', 'id': '1390-0'},
#   {'class': 'Moderate', 'name': 'isoflurophate ophthalmic', 'id': '1392-0'},
#   {'class': 'Moderate', 'name': 'isoniazid', 'id': '1393-0'},
#   {'class': 'Moderate', 'name': 'isoproterenol', 'id': '1397-0'},
#   {'class': 'Moderate', 'name': 'isosorbide', 'id': '1399-0'},
#   {'class': 'Moderate', 'name': 'isosorbide dinitrate', 'id': '1400-0'},
#   {'class': 'Moderate', 'name': 'isosorbide mononitrate', 'id': '1401-0'},
#   {'class': 'Moderate', 'name': 'isoxsuprine', 'id': '1404-0'},
#   {'class': 'Moderate', 'name': 'isradipine', 'id': '1405-0'},
#   {'class': 'Moderate', 'name': 'itraconazole', 'id': '1406-0'},
#   {'class': 'Moderate', 'name': 'ivacaftor', 'id': '3371-0'},
#   {'class': 'Moderate', 'name': 'ivosidenib', 'id': '3927-0'},
#   {'class': 'Moderate', 'name': 'kava', 'id': '2381-0'},
#   {'class': 'Major', 'name': 'ketamine', 'id': '1411-0'},
#   {'class': 'Moderate', 'name': 'ketoconazole', 'id': '1412-0'},
#   {'class': 'Moderate', 'name': 'labetalol', 'id': '1420-0'},
#   {'class': 'Moderate', 'name': 'lamotrigine', 'id': '1430-0'},
#   {'class': 'Moderate', 'name': 'lapatinib', 'id': '1436-0'},
#   {'class': 'Moderate', 'name': 'larotrectinib', 'id': '3980-0'},
#   {'class': 'Moderate', 'name': 'lasmiditan', 'id': '4095-0'},
#   {'class': 'Moderate', 'name': 'lefamulin', 'id': '4085-0'},
#   {'class': 'Moderate', 'name': 'lenvatinib', 'id': '3604-0'},
#   {'class': 'Moderate', 'name': 'lesinurad', 'id': '3725-0'},
#   {'class': 'Moderate', 'name': 'letermovir', 'id': '3873-0'},
#   {'class': 'Moderate', 'name': 'leuprolide', 'id': '1445-0'},
#   {'class': 'Moderate', 'name': 'levalbuterol', 'id': '1446-0'},
#   {'class': 'Moderate', 'name': 'levamlodipine', 'id': '4120-0'},
#   {'class': 'Moderate', 'name': 'levetiracetam', 'id': '1448-0'},
#   {'class': 'Moderate', 'name': 'levocetirizine', 'id': '1455-0'},
#   {'class': 'Moderate', 'name': 'levodopa', 'id': '1456-0'},
#   {'class': 'Moderate', 'name': 'levofloxacin', 'id': '1457-0'},
#   {'class': 'Moderate', 'name': 'levoketoconazole', 'id': '4330-0'},
#   {'class': 'Major', 'name': 'levomethadyl acetate', 'id': '1459-0'},
#   {'class': 'Moderate', 'name': 'levomilnacipran', 'id': '3483-0'},
#   {'class': 'Major', 'name': 'levorphanol', 'id': '1462-0'},
#   {'class': 'Moderate', 'name': 'linagliptin', 'id': '3322-0'},
#   {'class': 'Moderate', 'name': 'lindane topical', 'id': '1471-0'},
#   {'class': 'Moderate', 'name': 'liraglutide', 'id': '3189-0'},
#   {'class': 'Moderate', 'name': 'lisdexamfetamine', 'id': '1475-0'},
#   {'class': 'Moderate', 'name': 'lisinopril', 'id': '1476-0'},
#   {'class': 'Moderate', 'name': 'lithium', 'id': '1477-0'},
#   {'class': 'Moderate', 'name': 'lixisenatide', 'id': '3760-0'},
#   {'class': 'Moderate', 'name': 'lofexidine', 'id': '3910-0'},
#   {'class': 'Moderate', 'name': 'lomefloxacin', 'id': '1480-0'},
#   {'class': 'Moderate', 'name': 'lomitapide', 'id': '3437-0'},
#   {'class': 'Moderate', 'name': 'lonafarnib', 'id': '4203-0'},
#   {'class': 'Moderate', 'name': 'lonapegsomatropin', 'id': '4294-0'},
#   {'class': 'Moderate', 'name': 'loperamide', 'id': '1482-0'},
#   {'class': 'Moderate', 'name': 'lorazepam', 'id': '1488-0'},
#   {'class': 'Moderate', 'name': 'lorcaserin', 'id': '3401-0'},
#   {'class': 'Moderate', 'name': 'lorlatinib', 'id': '3974-0'},
#   {'class': 'Moderate', 'name': 'losartan', 'id': '1489-0'},
#   {'class': 'Moderate', 'name': 'loxapine', 'id': '1494-0'},
#   {'class': 'Moderate', 'name': 'lumateperone', 'id': '4114-0'},
#   {'class': 'Moderate', 'name': 'lurasidone', 'id': '3278-0'},
#   {'class': 'Moderate', 'name': 'macimorelin', 'id': '3886-0'},
#   {'class': 'Moderate', 'name': 'maprotiline', 'id': '1527-0'},
#   {'class': 'Moderate', 'name': 'mavacamten', 'id': '4360-0'},
#   {'class': 'Moderate', 'name': 'mecamylamine', 'id': '1536-0'},
#   {'class': 'Moderate', 'name': 'meclizine', 'id': '1540-0'},
#   {'class': 'Moderate', 'name': 'mefloquine', 'id': '1546-0'},
#   {'class': 'Moderate', 'name': 'melatonin', 'id': '1548-0'},
#   {'class': 'Moderate', 'name': 'memantine', 'id': '1551-0'},
#   {'class': 'Moderate', 'name': 'mepenzolate', 'id': '1556-0'},
#   {'class': 'Major', 'name': 'meperidine', 'id': '1557-0'},
#   {'class': 'Moderate', 'name': 'mephenytoin', 'id': '1560-0'},
#   {'class': 'Moderate', 'name': 'mephobarbital', 'id': '1561-0'},
#   {'class': 'Moderate', 'name': 'meprobamate', 'id': '1563-0'},
#   {'class': 'Moderate', 'name': 'mesoridazine', 'id': '1568-0'},
#   {'class': 'Moderate', 'name': 'metaproterenol', 'id': '1570-0'},
#   {'class': 'Moderate', 'name': 'metaxalone', 'id': '1572-0'},
#   {'class': 'Moderate', 'name': 'metformin', 'id': '1573-0'},
#   {'class': 'Major', 'name': 'methadone', 'id': '1578-0'},
#   {'class': 'Moderate', 'name': 'methdilazine', 'id': '1581-0'},
#   {'class': 'Moderate', 'name': 'methocarbamol', 'id': '1588-0'},
#   {'class': 'Moderate', 'name': 'methohexital', 'id': '1589-0'},
#   {'class': 'Moderate', 'name': 'methotrimeprazine', 'id': '1591-0'},
#   {'class': 'Moderate', 'name': 'methscopolamine', 'id': '1596-0'},
#   {'class': 'Moderate', 'name': 'methsuximide', 'id': '1598-0'},
#   {'class': 'Moderate', 'name': 'methyclothiazide', 'id': '1599-0'},
#   {'class': 'Moderate', 'name': 'methyldopa', 'id': '1603-0'},
#   {'class': 'Major', 'name': 'metoclopramide', 'id': '1612-0'},
#   {'class': 'Moderate', 'name': 'metolazone', 'id': '1614-0'},
#   {'class': 'Moderate', 'name': 'metoprolol', 'id': '1615-0'},
#   {'class': 'Major', 'name': 'metrizamide', 'id': '1616-0'},
#   {'class': 'Moderate', 'name': 'metronidazole', 'id': '1617-0'},
#   {'class': 'Moderate', 'name': 'metyrosine', 'id': '1620-0'},
#   {'class': 'Moderate', 'name': 'mibefradil', 'id': '1623-0'},
#   {'class': 'Moderate', 'name': 'miconazole', 'id': '1625-0'},
#   {'class': 'Moderate', 'name': 'midazolam', 'id': '1628-0'},
#   {'class': 'Moderate', 'name': 'midostaurin', 'id': '3804-0'},
#   {'class': 'Moderate', 'name': 'mifepristone', 'id': '1630-0'},
#   {'class': 'Moderate', 'name': 'miglitol', 'id': '1631-0'},
#   {'class': 'Moderate', 'name': 'milnacipran', 'id': '3101-0'},
#   {'class': 'Moderate', 'name': 'minoxidil', 'id': '1638-0'},
#   {'class': 'Moderate', 'name': 'mirabegron', 'id': '3402-0'},
#   {'class': 'Moderate', 'name': 'mirtazapine', 'id': '1640-0'},
#   {'class': 'Moderate', 'name': 'mitapivat', 'id': '4342-0'},
#   {'class': 'Moderate', 'name': 'mitotane', 'id': '1643-0'},
#   {'class': 'Moderate', 'name': 'mobocertinib', 'id': '4298-0'},
#   {'class': 'Minor', 'name': 'modafinil', 'id': '1647-0'},
#   {'class': 'Moderate', 'name': 'moexipril', 'id': '1648-0'},
#   {'class': 'Moderate', 'name': 'molindone', 'id': '1649-0'},
#   {'class': 'Major', 'name': 'morphine', 'id': '1656-0'},
#   {'class': 'Major', 'name': 'morphine liposomal', 'id': '1657-0'},
#   {'class': 'Moderate', 'name': 'moxifloxacin', 'id': '1659-0'},
#   {'class': 'Moderate', 'name': 'nabilone', 'id': '1673-0'},
#   {'class': 'Moderate', 'name': 'nadolol', 'id': '1675-0'},
#   {'class': 'Moderate', 'name': 'nafcillin', 'id': '1677-0'},
#   {'class': 'Major', 'name': 'nalbuphine', 'id': '1679-0'},
#   {'class': 'Moderate', 'name': 'nateglinide', 'id': '1695-0'},
#   {'class': 'Moderate', 'name': 'nebivolol', 'id': '2788-0'},
#   {'class': 'Moderate', 'name': 'nefazodone', 'id': '1698-0'},
#   {'class': 'Moderate', 'name': 'nelfinavir', 'id': '1700-0'},
#   {'class': 'Moderate', 'name': 'nevirapine', 'id': '1710-0'},
#   {'class': 'Moderate', 'name': 'nicardipine', 'id': '1713-0'},
#   {'class': 'Moderate', 'name': 'nifedipine', 'id': '1717-0'},
#   {'class': 'Moderate', 'name': 'nilotinib', 'id': '2785-0'},
#   {'class': 'Moderate', 'name': 'nilutamide', 'id': '1718-0'},
#   {'class': 'Moderate', 'name': 'nimodipine', 'id': '1719-0'},
#   {'class': 'Moderate', 'name': 'nisoldipine', 'id': '1720-0'},
#   {'class': 'Moderate', 'name': 'nitroglycerin', 'id': '2342-0'},
#   {'class': 'Moderate', 'name': 'nitroprusside', 'id': '1726-0'},
#   {'class': 'Moderate', 'name': 'norfloxacin', 'id': '1731-0'},
#   {'class': 'Moderate', 'name': 'nortriptyline', 'id': '1734-0'},
#   {'class': 'Moderate', 'name': 'ofloxacin', 'id': '1741-0'},
#   {'class': 'Moderate', 'name': 'olanzapine', 'id': '1744-0'},
#   {'class': 'Moderate', 'name': 'oliceridine', 'id': '4180-0'},
#   {'class': 'Moderate', 'name': 'olmesartan', 'id': '1745-0'},
#   {'class': 'Moderate', 'name': 'olodaterol', 'id': '3547-0'},
#   {'class': 'Moderate', 'name': 'olopatadine nasal', 'id': '2830-0'},
#   {'class': 'Moderate', 'name': 'ondansetron', 'id': '1752-0'},
#   {'class': 'Moderate', 'name': 'opicapone', 'id': '4148-0'},
#   {'class': 'Moderate', 'name': 'opium', 'id': '1754-0'},
#   {'class': 'Moderate', 'name': 'orphenadrine', 'id': '1757-0'},
#   {'class': 'Moderate', 'name': 'osilodrostat', 'id': '4141-0'},
#   {'class': 'Moderate', 'name': 'osimertinib', 'id': '3709-0'},
#   {'class': 'Moderate', 'name': 'oxaliplatin', 'id': '1760-0'},
#   {'class': 'Moderate', 'name': 'oxamniquine', 'id': '1761-0'},
#   {'class': 'Moderate', 'name': 'oxazepam', 'id': '1764-0'},
#   {'class': 'Moderate', 'name': 'oxcarbazepine', 'id': '1765-0'},
#   {'class': 'Moderate', 'name': 'oxybutynin', 'id': '1768-0'},
#   {'class': 'Major', 'name': 'oxycodone', 'id': '1770-0'},
#   {'class': 'Major', 'name': 'oxymorphone', 'id': '1773-0'},
#   {'class': 'Moderate', 'name': 'oxytocin', 'id': '1777-0'},
#   {'class': 'Major', 'name': 'ozanimod', 'id': '4142-0'},
#   {'class': 'Moderate', 'name': 'pacritinib', 'id': '4344-0'},
#   {'class': 'Moderate', 'name': 'palbociclib', 'id': '3602-0'},
#   {'class': 'Moderate', 'name': 'paliperidone', 'id': '1781-0'},
#   {'class': 'Moderate', 'name': 'palonosetron', 'id': '1783-0'},
#   {'class': 'Moderate', 'name': 'panobinostat', 'id': '3605-0'},
#   {'class': 'Moderate', 'name': 'papaverine', 'id': '1792-0'},
#   {'class': 'Moderate', 'name': 'paraldehyde', 'id': '1794-0'},
#   {'class': 'Moderate', 'name': 'paramethadione', 'id': '1795-0'},
#   {'class': 'Moderate', 'name': 'paroxetine', 'id': '1800-0'},
#   {'class': 'Moderate', 'name': 'pasireotide', 'id': '3435-0'},
#   {'class': 'Moderate', 'name': 'pazopanib', 'id': '3180-0'},
#   {'class': 'Moderate', 'name': 'penbutolol', 'id': '1812-0'},
#   {'class': 'Moderate', 'name': 'pentamidine', 'id': '1818-0'},
#   {'class': 'Major', 'name': 'pentazocine', 'id': '1820-0'},
#   {'class': 'Moderate', 'name': 'pentobarbital', 'id': '1823-0'},
#   {'class': 'Moderate', 'name': 'perampanel', 'id': '3426-0'},
#   {'class': 'Moderate', 'name': 'perflutren', 'id': '1828-0'},
#   {'class': 'Moderate', 'name': 'pergolide', 'id': '1829-0'},
#   {'class': 'Moderate', 'name': 'perindopril', 'id': '1830-0'},
#   {'class': 'Moderate', 'name': 'perphenazine', 'id': '1832-0'},
#   {'class': 'Moderate', 'name': 'pexidartinib', 'id': '4032-0'},
#   {'class': 'Moderate', 'name': 'phenacemide', 'id': '1834-0'},
#   {'class': 'Moderate', 'name': 'phenelzine', 'id': '1839-0'},
#   {'class': 'Moderate', 'name': 'phenindamine', 'id': '1840-0'},
#   {'class': 'Moderate', 'name': 'phenobarbital', 'id': '1846-0'},
#   {'class': 'Moderate', 'name': 'phenoxybenzamine', 'id': '1849-0'},
#   {'class': 'Moderate', 'name': 'phensuximide', 'id': '1850-0'},
#   {'class': 'Moderate', 'name': 'phentolamine', 'id': '1852-0'},
#   {'class': 'Moderate', 'name': 'phenylbutazone', 'id': '2770-0'},
#   {'class': 'Moderate', 'name': 'phenytoin', 'id': '1863-0'},
#   {'class': 'Moderate', 'name': 'physostigmine', 'id': '1866-0'},
#   {'class': 'Moderate', 'name': 'physostigmine ophthalmic', 'id': '1867-0'},
#   {'class': 'Moderate', 'name': 'pilocarpine ophthalmic', 'id': '1869-0'},
#   {'class': 'Moderate', 'name': 'pimavanserin', 'id': '3747-0'},
#   {'class': 'Moderate', 'name': 'pimozide', 'id': '1872-0'},
#   {'class': 'Moderate', 'name': 'pindolol', 'id': '1873-0'},
#   {'class': 'Moderate', 'name': 'pioglitazone', 'id': '1874-0'},
#   {'class': 'Moderate', 'name': 'pirbuterol', 'id': '1880-0'},
#   {'class': 'Moderate', 'name': 'pitolisant', 'id': '4081-0'},
#   {'class': 'Moderate',
#    'name': 'polyethylene glycol 3350 with electrolytes',
#    'id': '3155-0'},
#   {'class': 'Moderate', 'name': 'polythiazide', 'id': '1897-0'},
#   {'class': 'Moderate', 'name': 'ponesimod', 'id': '4247-0'},
#   {'class': 'Moderate', 'name': 'porfimer', 'id': '1901-0'},
#   {'class': 'Moderate', 'name': 'posaconazole', 'id': '1902-0'},
#   {'class': 'Moderate', 'name': 'pralsetinib', 'id': '4189-0'},
#   {'class': 'Moderate', 'name': 'pramipexole', 'id': '1925-0'},
#   {'class': 'Moderate', 'name': 'pramlintide', 'id': '1926-0'},
#   {'class': 'Moderate', 'name': 'prazosin', 'id': '1931-0'},
#   {'class': 'Moderate', 'name': 'pregabalin', 'id': '1937-0'},
#   {'class': 'Moderate', 'name': 'primaquine', 'id': '1939-0'},
#   {'class': 'Moderate', 'name': 'primidone', 'id': '1940-0'},
#   {'class': 'Moderate', 'name': 'probucol', 'id': '1942-0'},
#   {'class': 'Moderate', 'name': 'procainamide', 'id': '1943-0'},
#   {'class': 'Moderate', 'name': 'prochlorperazine', 'id': '1946-0'},
#   {'class': 'Moderate', 'name': 'procyclidine', 'id': '1947-0'},
#   {'class': 'Moderate', 'name': 'promazine', 'id': '1948-0'},
#   {'class': 'Moderate', 'name': 'promethazine', 'id': '1949-0'},
#   {'class': 'Moderate', 'name': 'propafenone', 'id': '1950-0'},
#   {'class': 'Moderate', 'name': 'propantheline', 'id': '1951-0'},
#   {'class': 'Moderate', 'name': 'propiomazine', 'id': '1953-0'},
#   {'class': 'Moderate', 'name': 'propofol', 'id': '1954-0'},
#   {'class': 'Major', 'name': 'propoxyphene', 'id': '1955-0'},
#   {'class': 'Moderate', 'name': 'propranolol', 'id': '1956-0'},
#   {'class': 'Moderate', 'name': 'protriptyline', 'id': '1962-0'},
#   {'class': 'Moderate', 'name': 'pyrilamine', 'id': '1973-0'},
#   {'class': 'Moderate', 'name': 'quazepam', 'id': '1978-0'},
#   {'class': 'Moderate', 'name': 'quetiapine', 'id': '1979-0'},
#   {'class': 'Moderate', 'name': 'quinapril', 'id': '1980-0'},
#   {'class': 'Moderate', 'name': 'quinidine', 'id': '1981-0'},
#   {'class': 'Moderate', 'name': 'quinine', 'id': '1982-0'},
#   {'class': 'Moderate', 'name': 'ramelteon', 'id': '1988-0'},
#   {'class': 'Moderate', 'name': 'ramipril', 'id': '1989-0'},
#   {'class': 'Moderate', 'name': 'ranolazine', 'id': '1993-0'},
#   {'class': 'Moderate', 'name': 'rasagiline', 'id': '1995-0'},
#   {'class': 'Moderate', 'name': 'rauwolfia serpentina', 'id': '1997-0'},
#   {'class': 'Moderate', 'name': 'relugolix', 'id': '4227-0'},
#   {'class': 'Major', 'name': 'remifentanil', 'id': '1999-0'},
#   {'class': 'Moderate', 'name': 'remimazolam', 'id': '4165-0'},
#   {'class': 'Moderate', 'name': 'repaglinide', 'id': '2000-0'},
#   {'class': 'Moderate', 'name': 'reserpine', 'id': '2001-0'},
#   {'class': 'Moderate', 'name': 'revefenacin', 'id': '3975-0'},
#   {'class': 'Moderate', 'name': 'ribociclib', 'id': '3790-0'},
#   {'class': 'Moderate', 'name': 'rifabutin', 'id': '2011-0'},
#   {'class': 'Moderate', 'name': 'rifampin', 'id': '2012-0'},
#   {'class': 'Moderate', 'name': 'rifapentine', 'id': '2013-0'},
#   {'class': 'Moderate', 'name': 'rilpivirine', 'id': '3327-0'},
#   {'class': 'Moderate', 'name': 'risperidone', 'id': '2019-0'},
#   {'class': 'Moderate', 'name': 'ritodrine', 'id': '2020-0'},
#   {'class': 'Moderate', 'name': 'ritonavir', 'id': '2021-0'},
#   {'class': 'Moderate', 'name': 'rivastigmine', 'id': '2023-0'},
#   {'class': 'Moderate', 'name': 'rolapitant', 'id': '3678-0'},
#   {'class': 'Moderate', 'name': 'romidepsin', 'id': '3183-0'},
#   {'class': 'Moderate', 'name': 'ropinirole', 'id': '2027-0'},
#   {'class': 'Moderate', 'name': 'rosiglitazone', 'id': '2030-0'},
#   {'class': 'Moderate', 'name': 'rotigotine', 'id': '2033-0'},
#   {'class': 'Moderate', 'name': 'rucaparib', 'id': '3778-0'},
#   {'class': 'Moderate', 'name': 'safinamide', 'id': '3793-0'},
#   {'class': 'Moderate', 'name': 'salmeterol', 'id': '2041-0'},
#   {'class': 'Moderate', 'name': 'saquinavir', 'id': '2044-0'},
#   {'class': 'Moderate', 'name': 'saxagliptin', 'id': '3160-0'},
#   {'class': 'Moderate', 'name': 'scopolamine', 'id': '2047-0'},
#   {'class': 'Moderate', 'name': 'secobarbital', 'id': '2049-0'},
#   {'class': 'Moderate', 'name': 'selegiline', 'id': '2051-0'},
#   {'class': 'Moderate', 'name': 'selpercatinib', 'id': '4151-0'},
#   {'class': 'Moderate', 'name': 'semaglutide', 'id': '3878-0'},
#   {'class': 'Moderate', 'name': 'sertraline', 'id': '2057-0'},
#   {'class': 'Moderate', 'name': 'sevoflurane', 'id': '2059-0'},
#   {'class': 'Moderate', 'name': 'sibutramine', 'id': '2060-0'},
#   {'class': 'Moderate', 'name': 'silodosin', 'id': '2960-0'},
#   {'class': 'Moderate', 'name': 'siponimod', 'id': '4001-0'},
#   {'class': 'Moderate', 'name': 'sirolimus', 'id': '2069-0'},
#   {'class': 'Moderate', 'name': 'sitagliptin', 'id': '2070-0'},
#   {'class': 'Major', 'name': 'sodium oxybate', 'id': '2091-0'},
#   {'class': 'Moderate', 'name': 'solifenacin', 'id': '2098-0'},
#   {'class': 'Moderate', 'name': 'somapacitan-beco', 'id': '4188-0'},
#   {'class': 'Moderate', 'name': 'somatrem', 'id': '2099-0'},
#   {'class': 'Moderate', 'name': 'somatropin', 'id': '2100-0'},
#   {'class': 'Moderate', 'name': 'sorafenib', 'id': '2101-0'},
#   {'class': 'Moderate', 'name': 'sotalol', 'id': '2102-0'},
#   {'class': 'Moderate', 'name': 'sotorasib', 'id': '4266-0'},
#   {'class': 'Moderate', 'name': 'sparfloxacin', 'id': '2103-0'},
#   {'class': 'Moderate', 'name': 'spironolactone', 'id': '2105-0'},
#   {'class': 'Moderate', 'name': "st. john's wort", 'id': '2106-0'},
#   {'class': 'Moderate', 'name': 'stiripentol', 'id': '3952-0'},
#   {'class': 'Major', 'name': 'sufentanil', 'id': '2119-0'},
#   {'class': 'Minor', 'name': 'sulfamethoxazole', 'id': '2127-0'},
#   {'class': 'Moderate', 'name': 'sulfinpyrazone', 'id': '2131-0'},
#   {'class': 'Moderate', 'name': 'sunitinib', 'id': '2138-0'},
#   {'class': 'Moderate', 'name': 'suvorexant', 'id': '3554-0'},
#   {'class': 'Moderate', 'name': 'tacrine', 'id': '2141-0'},
#   {'class': 'Moderate', 'name': 'tacrolimus', 'id': '2142-0'},
#   {'class': 'Moderate', 'name': 'tamoxifen', 'id': '2145-0'},
#   {'class': 'Moderate', 'name': 'tamsulosin', 'id': '2146-0'},
#   {'class': 'Major', 'name': 'tapentadol', 'id': '3132-0'},
#   {'class': 'Moderate', 'name': 'tasimelteon', 'id': '3507-0'},
#   {'class': 'Moderate', 'name': 'tazemetostat', 'id': '4127-0'},
#   {'class': 'Moderate', 'name': 'telaprevir', 'id': '3328-0'},
#   {'class': 'Moderate', 'name': 'telavancin', 'id': '3173-0'},
#   {'class': 'Moderate', 'name': 'telithromycin', 'id': '2151-0'},
#   {'class': 'Moderate', 'name': 'telmisartan', 'id': '2152-0'},
#   {'class': 'Moderate', 'name': 'telotristat', 'id': '3787-0'},
#   {'class': 'Moderate', 'name': 'temazepam', 'id': '2153-0'},
#   {'class': 'Moderate', 'name': 'temsirolimus', 'id': '2155-0'},
#   {'class': 'Moderate', 'name': 'terazosin', 'id': '2159-0'},
#   {'class': 'Moderate', 'name': 'terbinafine', 'id': '2161-0'},
#   {'class': 'Moderate', 'name': 'terbutaline', 'id': '2162-0'},
#   {'class': 'Moderate', 'name': 'terfenadine', 'id': '2164-0'},
#   {'class': 'Major', 'name': 'tetrabenazine', 'id': '2918-0'},
#   {'class': 'Moderate', 'name': 'thalidomide', 'id': '2176-0'},
#   {'class': 'Moderate', 'name': 'thiethylperazine', 'id': '2180-0'},
#   {'class': 'Moderate', 'name': 'thiopental', 'id': '2183-0'},
#   {'class': 'Moderate', 'name': 'thioridazine', 'id': '2184-0'},
#   {'class': 'Moderate', 'name': 'thiothixene', 'id': '2186-0'},
#   {'class': 'Moderate', 'name': 'tiagabine', 'id': '2191-0'},
#   {'class': 'Moderate', 'name': 'ticagrelor', 'id': '3336-0'},
#   {'class': 'Moderate', 'name': 'ticlopidine', 'id': '2193-0'},
#   {'class': 'Moderate', 'name': 'timolol', 'id': '2196-0'},
#   {'class': 'Moderate', 'name': 'tiotropium', 'id': '2202-0'},
#   {'class': 'Moderate', 'name': 'tirzepatide', 'id': '4363-0'},
#   {'class': 'Moderate', 'name': 'tizanidine', 'id': '2205-0'},
#   {'class': 'Moderate', 'name': 'tolazamide', 'id': '2209-0'},
#   {'class': 'Moderate', 'name': 'tolazoline', 'id': '2210-0'},
#   {'class': 'Moderate', 'name': 'tolbutamide', 'id': '2211-0'},
#   {'class': 'Moderate', 'name': 'tolcapone', 'id': '2212-0'},
#   {'class': 'Moderate', 'name': 'tolterodine', 'id': '2215-0'},
#   {'class': 'Major', 'name': 'topiramate', 'id': '2216-0'},
#   {'class': 'Moderate', 'name': 'toremifene', 'id': '2218-0'},
#   {'class': 'Moderate', 'name': 'torsemide', 'id': '2219-0'},
#   {'class': 'Major', 'name': 'tramadol', 'id': '2221-0'},
#   {'class': 'Moderate', 'name': 'trandolapril', 'id': '2222-0'},
#   {'class': 'Moderate', 'name': 'tranylcypromine', 'id': '2225-0'},
#   {'class': 'Moderate', 'name': 'trazodone', 'id': '2228-0'},
#   {'class': 'Moderate', 'name': 'triamterene', 'id': '2234-0'},
#   {'class': 'Moderate', 'name': 'triazolam', 'id': '2235-0'},
#   {'class': 'Moderate', 'name': 'trichlormethiazide', 'id': '2236-0'},
#   {'class': 'Moderate', 'name': 'triclabendazole', 'id': '3995-0'},
#   {'class': 'Moderate', 'name': 'trifluoperazine', 'id': '2242-0'},
#   {'class': 'Moderate', 'name': 'triflupromazine', 'id': '2243-0'},
#   {'class': 'Moderate', 'name': 'trihexyphenidyl', 'id': '2245-0'},
#   {'class': 'Moderate', 'name': 'trimeprazine', 'id': '2246-0'},
#   {'class': 'Moderate', 'name': 'trimethadione', 'id': '2247-0'},
#   {'class': 'Moderate', 'name': 'trimethaphan camsylate', 'id': '2248-0'},
#   {'class': 'Moderate', 'name': 'trimethobenzamide', 'id': '2249-0'},
#   {'class': 'Moderate', 'name': 'trimipramine', 'id': '2252-0'},
#   {'class': 'Moderate', 'name': 'tripelennamine', 'id': '2254-0'},
#   {'class': 'Moderate', 'name': 'triprolidine', 'id': '2257-0'},
#   {'class': 'Moderate', 'name': 'triptorelin', 'id': '2258-0'},
#   {'class': 'Moderate', 'name': 'troglitazone', 'id': '2259-0'},
#   {'class': 'Moderate', 'name': 'troleandomycin', 'id': '2261-0'},
#   {'class': 'Moderate', 'name': 'trospium', 'id': '2264-0'},
#   {'class': 'Moderate', 'name': 'tucatinib', 'id': '4144-0'},
#   {'class': 'Moderate', 'name': 'umeclidinium', 'id': '3528-0'},
#   {'class': 'Moderate', 'name': 'valbenazine', 'id': '3800-0'},
#   {'class': 'Moderate', 'name': 'valerian', 'id': '2284-0'},
#   {'class': 'Moderate', 'name': 'valproic acid', 'id': '2286-0'},
#   {'class': 'Moderate', 'name': 'valsartan', 'id': '2288-0'},
#   {'class': 'Moderate', 'name': 'vandetanib', 'id': '3312-0'},
#   {'class': 'Moderate', 'name': 'vardenafil', 'id': '2290-0'},
#   {'class': 'Moderate', 'name': 'vasopressin', 'id': '2294-0'},
#   {'class': 'Moderate', 'name': 'vemurafenib', 'id': '3338-0'},
#   {'class': 'Moderate', 'name': 'venlafaxine', 'id': '2296-0'},
#   {'class': 'Moderate', 'name': 'verapamil', 'id': '2297-0'},
#   {'class': 'Moderate', 'name': 'vigabatrin', 'id': '3169-0'},
#   {'class': 'Moderate', 'name': 'viloxazine', 'id': '4254-0'},
#   {'class': 'Moderate', 'name': 'voclosporin', 'id': '4234-0'},
#   {'class': 'Moderate', 'name': 'voriconazole', 'id': '2309-0'},
#   {'class': 'Moderate', 'name': 'voxelotor', 'id': '4107-0'},
#   {'class': 'Moderate', 'name': 'zafirlukast', 'id': '2317-0'},
#   {'class': 'Moderate', 'name': 'zaleplon', 'id': '2319-0'},
#   {'class': 'Moderate', 'name': 'ziconotide', 'id': '2321-0'},
#   {'class': 'Moderate', 'name': 'ziprasidone', 'id': '2330-0'},
#   {'class': 'Moderate', 'name': 'zolpidem', 'id': '2333-0'},
#   {'class': 'Major', 'name': 'zonisamide', 'id': '2334-0'}]}

# %%
drugs_interactions_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 drugs_interactions_list
#
# NameError: name 'drugs_interactions_list' is not defined
